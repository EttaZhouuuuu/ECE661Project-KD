# %% [markdown]
# Import and Set up

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import time
import copy
import matplotlib.pyplot as plt
import os # For Colab path handling

# Check for GPU availability and set device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %% [markdown]
# Connect to Google Dirve

# %%
# Cell 1.5: Mount Google Drive and Ensure Directories
from google.colab import drive
# import os # Ensure os is imported

drive.mount('/content/drive')

# --- Define BASE paths for directories in your Google Drive ---
DRIVE_PROJECT_BASE = '/content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation'
MODELS_DIR_PATH = os.path.join(DRIVE_PROJECT_BASE, 'models')
RESULTS_DIR_PATH = os.path.join(DRIVE_PROJECT_BASE, 'results')

# --- Ensure the target directories exist in Drive ---
for path_to_check in [MODELS_DIR_PATH, RESULTS_DIR_PATH]:
    try:
        os.makedirs(path_to_check, exist_ok=True)
        print(f"Directory ensured at: {path_to_check}")
    except OSError as e:
        print(f"Error creating directory {path_to_check}: {e}")
        # Provide more context if needed
    except Exception as e:
         print(f"An unexpected error occurred while checking/creating {path_to_check}: {e}")
# Out:
# Mounted at /content/drive
# Directory ensured at: /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models
# Directory ensured at: /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/results

# %% [markdown]
# Hyperparameters and Configuration

# %%
# Configuration based on typical ResNet training on CIFAR-10
BATCH_SIZE = 128
LEARNING_RATE = 0.1 # Initial learning rate for SGD
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4 # L2 regularization
EPOCHS = 100 # Adjust as needed, Self-Distillation might converge differently
NUM_CLASSES = 10 # CIFAR-10 has 10 classes

# Learning Rate Scheduler Milestones
LR_MILESTONES = [int(EPOCHS * 0.5), int(EPOCHS * 0.75)] # Adjust if EPOCHS change significantly
LR_GAMMA = 0.1 # Factor to reduce LR by

# --- Self-Distillation Hyperparameters ---
TEMPERATURE = 3.0 # Temperature for softening probabilities
W_AUX_CE = 0.4   # Weight for auxiliary classifier Cross-Entropy losses
W_KD = 0.6     # Weight for Knowledge Distillation (KL Div) losses
# Note: You might need to tune T, W_AUX_CE, W_KD

# --- Define Model and Plot Filenames ---
MODEL_FILENAME = f'resnet50_self_distill_T{TEMPERATURE}_Waux{W_AUX_CE}_Wkd{W_KD}.pth' # <<< Updated filename with SD params
PLOT_FILENAME = f'resnet50_self_distill_T{TEMPERATURE}_Waux{W_AUX_CE}_Wkd{W_KD}_curves.png' # <<< Updated filename

# --- Construct full paths using variables from Cell 1.5 ---
MODEL_SAVE_PATH = os.path.join(MODELS_DIR_PATH, MODEL_FILENAME)
PLOT_SAVE_PATH = os.path.join(RESULTS_DIR_PATH, PLOT_FILENAME)

print(f"Epochs: {EPOCHS}")
print(f"Batch Size: {BATCH_SIZE}")
print(f"Initial Learning Rate: {LEARNING_RATE}")
print(f"LR Milestones: {LR_MILESTONES}")
print(f"Temperature (T): {TEMPERATURE}")
print(f"Aux CE Loss Weight: {W_AUX_CE}")
print(f"KD Loss Weight: {W_KD}")
print(f"Model will be saved to: {MODEL_SAVE_PATH}")
print(f"Plot will be saved to: {PLOT_SAVE_PATH}")
# Out:
# Epochs: 100
# Batch Size: 128
# Initial Learning Rate: 0.1
# LR Milestones: [50, 75]
# Temperature (T): 3.0
# Aux CE Loss Weight: 0.4
# KD Loss Weight: 0.6
# Model will be saved to: /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
# Plot will be saved to: /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/results/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6_curves.png

# %% [markdown]
# Data Loading and Transforming

# %%
print("Setting up CIFAR-10 data transformations...")
# Normalization values for CIFAR-10
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

print("Loading CIFAR-10 dataset...")
# Use /content/data for Colab storage
trainset = torchvision.datasets.CIFAR10(
    root='/content/data', train=True, download=True, transform=transform_train)
trainloader = DataLoader(
    trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(
    root='/content/data', train=False, download=True, transform=transform_test)
testloader = DataLoader(
    testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

print("Dataset loaded.")
print(f"Training set size: {len(trainset)}")
print(f"Test set size: {len(testset)}")
# Out:
# Setting up CIFAR-10 data transformations...
# Loading CIFAR-10 dataset...
# 100%|██████████| 170M/170M [00:12<00:00, 13.2MB/s]
# Dataset loaded.
# Training set size: 50000
# Test set size: 10000

# %% [markdown]
# Model Definition (ResNet-50 Baseline)

# %%
print("Defining ResNet-50 model with auxiliary classifiers for Self-Distillation...")

# Load ResNet-50 architecture.
# We'll use its layers but define a custom forward pass.
base_model = torchvision.models.resnet50(weights=None) # Start with random weights

class ResNet50_SD(nn.Module):
    def __init__(self, base_model, num_classes=10):
        super(ResNet50_SD, self).__init__()
        # Use layers from the base ResNet-50
        self.conv1 = base_model.conv1
        self.bn1 = base_model.bn1
        self.relu = base_model.relu
        self.maxpool = base_model.maxpool
        self.layer1 = base_model.layer1
        self.layer2 = base_model.layer2
        self.layer3 = base_model.layer3
        self.layer4 = base_model.layer4
        self.avgpool = base_model.avgpool

        # Original final classifier (Teacher / Final Output)
        self.fc_final = nn.Linear(base_model.fc.in_features, num_classes)

        # --- Add Auxiliary Classifiers ---
        # After layer 2 (ResNet-50 layer2 output channels: 512)
        self.avgpool_aux2 = nn.AdaptiveAvgPool2d((1, 1))
        self.fc_aux2 = nn.Linear(512, num_classes)

        # After layer 3 (ResNet-50 layer3 output channels: 1024)
        self.avgpool_aux3 = nn.AdaptiveAvgPool2d((1, 1))
        self.fc_aux3 = nn.Linear(1024, num_classes)

        print("Auxiliary classifiers added after layer2 and layer3.")

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.layer1(x)
        out_layer2 = self.layer2(x) # Output after layer 2

        # Auxiliary Classifier 2 Path
        aux2 = self.avgpool_aux2(out_layer2)
        aux2 = torch.flatten(aux2, 1)
        out_aux2 = self.fc_aux2(aux2)

        out_layer3 = self.layer3(out_layer2) # Output after layer 3

        # Auxiliary Classifier 3 Path
        aux3 = self.avgpool_aux3(out_layer3)
        aux3 = torch.flatten(aux3, 1)
        out_aux3 = self.fc_aux3(aux3)

        out_layer4 = self.layer4(out_layer3) # Output after layer 4 (final features)

        # Final Classifier Path
        final = self.avgpool(out_layer4)
        final = torch.flatten(final, 1)
        out_final = self.fc_final(final)

        # Return all relevant outputs for training
        return out_final, out_aux2, out_aux3

# Instantiate the SD model
model = ResNet50_SD(base_model, num_classes=NUM_CLASSES)
print("ResNet-50 Self-Distillation model defined.")
# Out:
# Defining ResNet-50 model with auxiliary classifiers for Self-Distillation...
# Auxiliary classifiers added after layer2 and layer3.
# ResNet-50 Self-Distillation model defined.

# %% [markdown]
# Cell 5: Instantiate Model, Loss, Optimizer, Scheduler (Add KLDivLoss)

# %%
print("Instantiating ResNet-50_SD model...")
# model is already defined and instantiated in Cell 4

model = model.to(DEVICE) # Move model defined in Cell 4 to the device
print("Model instantiated and moved to device.")

# Standard Loss Function (for final and auxiliary CE)
criterion_ce = nn.CrossEntropyLoss()
print("Loss function (CE): CrossEntropyLoss")

# Distillation Loss Function (KL Divergence)
# reduction='batchmean' averages the loss per batch *before* dividing by N.
# Use reduction='mean' if you want loss averaged over all elements. 'batchmean' is common for KD.
criterion_kd = nn.KLDivLoss(reduction='batchmean')
print("Loss function (KD): KLDivLoss (reduction='batchmean')")


# Optimizer (SGD is standard for ResNets on CIFAR)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE,
                      momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
print(f"Optimizer: SGD (LR={LEARNING_RATE}, Momentum={MOMENTUM}, WD={WEIGHT_DECAY})")

# Learning Rate Scheduler
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=LR_MILESTONES, gamma=LR_GAMMA)
print(f"LR Scheduler: MultiStepLR (milestones={LR_MILESTONES}, gamma={LR_GAMMA})")
# Out:
# Instantiating ResNet-50_SD model...
# Model instantiated and moved to device.
# Loss function (CE): CrossEntropyLoss
# Loss function (KD): KLDivLoss (reduction='batchmean')
# Optimizer: SGD (LR=0.1, Momentum=0.9, WD=0.0005)
# LR Scheduler: MultiStepLR (milestones=[50, 75], gamma=0.1)

# %% [markdown]
# Training and Validation Functions

# %%
def train_one_epoch_sd(epoch, model, trainloader, optimizer, criterion_ce, criterion_kd, device, temp, w_aux_ce, w_kd):
    model.train() # Set model to training mode
    running_loss = 0.0
    running_loss_final_ce = 0.0
    running_loss_aux_ce = 0.0
    running_loss_kd = 0.0
    correct_final = 0 # Track accuracy only based on the final classifier
    total = 0
    start_time = time.time()
    print_freq = len(trainloader) // 4 # Print progress roughly 4 times per epoch

    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass - get all outputs
        out_final, out_aux2, out_aux3 = model(inputs)

        # --- Calculate Loss Components ---
        # 1. Final Classifier Cross-Entropy Loss
        loss_final_ce = criterion_ce(out_final, labels)

        # 2. Auxiliary Classifiers Cross-Entropy Loss
        loss_aux2_ce = criterion_ce(out_aux2, labels)
        loss_aux3_ce = criterion_ce(out_aux3, labels)
        loss_aux_ce_total = loss_aux2_ce + loss_aux3_ce

        # 3. Knowledge Distillation Loss (Final teaches Aux)
        # Use log_softmax for student predictions and softmax for teacher predictions
        # Teacher predictions should be detached from the graph
        teacher_prob = F.softmax(out_final / temp, dim=1).detach()

        loss_kd2 = criterion_kd(
            F.log_softmax(out_aux2 / temp, dim=1),
            teacher_prob
        ) * (temp * temp) # Scaling factor, common practice for KLDiv with temperature

        loss_kd3 = criterion_kd(
            F.log_softmax(out_aux3 / temp, dim=1),
            teacher_prob
        ) * (temp * temp) # Scaling factor

        loss_kd_total = loss_kd2 + loss_kd3

        # --- Calculate Total Weighted Loss ---
        total_loss = loss_final_ce + w_aux_ce * loss_aux_ce_total + w_kd * loss_kd_total

        # Backward + optimize
        total_loss.backward()
        optimizer.step()

        # --- Statistics ---
        running_loss += total_loss.item()
        running_loss_final_ce += loss_final_ce.item()
        running_loss_aux_ce += loss_aux_ce_total.item()
        running_loss_kd += loss_kd_total.item()

        # Accuracy is calculated ONLY based on the final classifier's output
        _, predicted_final = torch.max(out_final.data, 1)
        total += labels.size(0)
        correct_final += (predicted_final == labels).sum().item()

        # Print progress
        if (i + 1) % print_freq == 0 or (i + 1) == len(trainloader):
             print(f'Epoch [{epoch + 1}/{EPOCHS}], Step [{i + 1}/{len(trainloader)}], '
                   f'Loss: {running_loss / (i + 1):.4f} '
                   f'(FinalCE: {running_loss_final_ce / (i + 1):.4f}, '
                   f'AuxCE: {running_loss_aux_ce / (i + 1):.4f}, '
                   f'KD: {running_loss_kd / (i + 1):.4f})')

    epoch_time = time.time() - start_time
    epoch_loss = running_loss / len(trainloader)
    epoch_acc_final = 100. * correct_final / total # Report accuracy based on final layer
    print(f'---> Epoch {epoch + 1} Training Summary: Avg Loss: {epoch_loss:.4f}, Final Acc: {epoch_acc_final:.2f}%, Time: {epoch_time:.2f}s')
    # Return avg total loss and final accuracy for history tracking
    return epoch_loss, epoch_acc_final

# --- Validation Function ---
# IMPORTANT: Validation uses ONLY the final output, standard CE Loss
def validate_sd(model, testloader, criterion_ce, device):
    model.eval() # Set model to evaluation mode
    running_loss = 0.0
    correct = 0
    total = 0
    start_time = time.time()
    with torch.no_grad(): # No need to track gradients during validation
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            # --- Get ONLY the final output for validation ---
            outputs_final, _, _ = model(images) # Ignore auxiliary outputs

            loss = criterion_ce(outputs_final, labels) # Use standard CE loss

            running_loss += loss.item()
            _, predicted = torch.max(outputs_final.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    epoch_time = time.time() - start_time
    val_loss = running_loss / len(testloader)
    val_acc = 100. * correct / total
    print(f'---> Validation Summary (using final output): Loss: {val_loss:.4f}, Acc: {val_acc:.2f}%, Time: {epoch_time:.2f}s')
    # Return validation loss and accuracy based on final layer
    return val_loss, val_acc

print("Self-Distillation training and validation functions defined.")
# Out:
# Self-Distillation training and validation functions defined.

# %% [markdown]
# Main Training Loop

# %%
print(f"Starting Self-Distillation Training for {EPOCHS} epochs...")
start_train_time = time.time()

best_val_acc = 0.0
# No need to initialize best_model_wts here, just save directly

# History tracking for plots (tracking total train loss and final val acc)
history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'lr': []}

for epoch in range(EPOCHS):
    print(f"\n--- Epoch {epoch + 1}/{EPOCHS} ---")
    current_lr = optimizer.param_groups[0]['lr']
    print(f"Current Learning Rate: {current_lr:.6f}")
    history['lr'].append(current_lr)

    # Train for one epoch using the Self-Distillation training function
    # Pass the extra hyperparameters (temp, w_aux_ce, w_kd)
    train_loss, train_acc = train_one_epoch_sd(
        epoch, model, trainloader, optimizer, criterion_ce, criterion_kd, DEVICE,
        TEMPERATURE, W_AUX_CE, W_KD
    )

    # Validate the model using the Self-Distillation validation function
    val_loss, val_acc = validate_sd(model, testloader, criterion_ce, DEVICE)

    # Store history (Train loss is total loss, Acc is based on final layer)
    history['train_loss'].append(train_loss)
    history['train_acc'].append(train_acc) # Final layer train acc
    history['val_loss'].append(val_loss)   # Final layer val loss
    history['val_acc'].append(val_acc)     # Final layer val acc

    # Update learning rate using the scheduler
    scheduler.step()

    # Save the best model based on validation accuracy (measured on final layer)
    if val_acc > best_val_acc:
        print(f"Validation accuracy improved ({best_val_acc:.2f}% -> {val_acc:.2f}%). Saving model...")
        best_val_acc = val_acc
        # Save the model state dict directly to the path defined in Cell 2
        try:
            torch.save(model.state_dict(), MODEL_SAVE_PATH)
            print(f"Model saved to {MODEL_SAVE_PATH}")
        except Exception as e:
            print(f"Error saving model to {MODEL_SAVE_PATH}: {e}")


total_train_time = time.time() - start_train_time
print("\nFinished Self-Distillation Training.")
print(f"Total Training Time: {total_train_time // 60:.0f}m {total_train_time % 60:.0f}s")
print(f"Best Validation Accuracy achieved (on final layer): {best_val_acc:.2f}%")
print(f"Best model saved at: {MODEL_SAVE_PATH}")
# Out:
# Starting Self-Distillation Training for 100 epochs...
#
# --- Epoch 1/100 ---
# Current Learning Rate: 0.100000
# Epoch [1/100], Step [97/391], Loss: 37.6782 (FinalCE: 10.0956, AuxCE: 15.5498, KD: 35.6045)
# Epoch [1/100], Step [194/391], Loss: 21.9996 (FinalCE: 7.0285, AuxCE: 10.1684, KD: 18.1729)
# Epoch [1/100], Step [291/391], Loss: 16.1890 (FinalCE: 5.5322, AuxCE: 8.3179, KD: 12.2161)
# Epoch [1/100], Step [388/391], Loss: 13.2288 (FinalCE: 4.7488, AuxCE: 7.3850, KD: 9.2100)
# Epoch [1/100], Step [391/391], Loss: 13.1608 (FinalCE: 4.7306, AuxCE: 7.3637, KD: 9.1411)
# ---> Epoch 1 Training Summary: Avg Loss: 13.1608, Final Acc: 9.91%, Time: 31.40s
# ---> Validation Summary (using final output): Loss: 2.3339, Acc: 10.12%, Time: 2.65s
# Validation accuracy improved (0.00% -> 10.12%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 2/100 ---
# Current Learning Rate: 0.100000
# Epoch [2/100], Step [97/391], Loss: 4.2409 (FinalCE: 2.3501, AuxCE: 4.5733, KD: 0.1025)
# Epoch [2/100], Step [194/391], Loss: 4.2150 (FinalCE: 2.3359, AuxCE: 4.5694, KD: 0.0855)
# Epoch [2/100], Step [291/391], Loss: 4.1979 (FinalCE: 2.3285, AuxCE: 4.5632, KD: 0.0734)
# Epoch [2/100], Step [388/391], Loss: 4.1846 (FinalCE: 2.3234, AuxCE: 4.5575, KD: 0.0637)
# Epoch [2/100], Step [391/391], Loss: 4.1842 (FinalCE: 2.3232, AuxCE: 4.5573, KD: 0.0634)
# ---> Epoch 2 Training Summary: Avg Loss: 4.1842, Final Acc: 10.09%, Time: 28.70s
# ---> Validation Summary (using final output): Loss: 2.3120, Acc: 10.06%, Time: 3.14s
#
# --- Epoch 3/100 ---
# Current Learning Rate: 0.100000
# Epoch [3/100], Step [97/391], Loss: 4.1331 (FinalCE: 2.3065, AuxCE: 4.5193, KD: 0.0315)
# Epoch [3/100], Step [194/391], Loss: 4.1273 (FinalCE: 2.3058, AuxCE: 4.5063, KD: 0.0316)
# Epoch [3/100], Step [291/391], Loss: 4.1224 (FinalCE: 2.3050, AuxCE: 4.4912, KD: 0.0348)
# Epoch [3/100], Step [388/391], Loss: 4.1183 (FinalCE: 2.3047, AuxCE: 4.4793, KD: 0.0365)
# Epoch [3/100], Step [391/391], Loss: 4.1182 (FinalCE: 2.3047, AuxCE: 4.4790, KD: 0.0365)
# ---> Epoch 3 Training Summary: Avg Loss: 4.1182, Final Acc: 10.07%, Time: 28.38s
# ---> Validation Summary (using final output): Loss: 2.3054, Acc: 9.98%, Time: 2.57s
#
# --- Epoch 4/100 ---
# Current Learning Rate: 0.100000
# Epoch [4/100], Step [97/391], Loss: 4.1044 (FinalCE: 2.3054, AuxCE: 4.4310, KD: 0.0444)
# Epoch [4/100], Step [194/391], Loss: 4.1022 (FinalCE: 2.3045, AuxCE: 4.4254, KD: 0.0458)
# Epoch [4/100], Step [291/391], Loss: 4.1002 (FinalCE: 2.3039, AuxCE: 4.4210, KD: 0.0465)
# Epoch [4/100], Step [388/391], Loss: 4.0987 (FinalCE: 2.3031, AuxCE: 4.4175, KD: 0.0476)
# Epoch [4/100], Step [391/391], Loss: 4.0986 (FinalCE: 2.3031, AuxCE: 4.4174, KD: 0.0476)
# ---> Epoch 4 Training Summary: Avg Loss: 4.0986, Final Acc: 10.19%, Time: 28.56s
# ---> Validation Summary (using final output): Loss: 2.2956, Acc: 14.12%, Time: 2.56s
# Validation accuracy improved (10.12% -> 14.12%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 5/100 ---
# Current Learning Rate: 0.100000
# Epoch [5/100], Step [97/391], Loss: 3.8985 (FinalCE: 2.0934, AuxCE: 4.2003, KD: 0.2083)
# Epoch [5/100], Step [194/391], Loss: 3.7950 (FinalCE: 2.0334, AuxCE: 4.0996, KD: 0.2030)
# Epoch [5/100], Step [291/391], Loss: 3.7328 (FinalCE: 1.9926, AuxCE: 4.0390, KD: 0.2078)
# Epoch [5/100], Step [388/391], Loss: 3.6958 (FinalCE: 1.9616, AuxCE: 4.0029, KD: 0.2217)
# Epoch [5/100], Step [391/391], Loss: 3.6946 (FinalCE: 1.9609, AuxCE: 4.0015, KD: 0.2219)
# ---> Epoch 5 Training Summary: Avg Loss: 3.6946, Final Acc: 24.03%, Time: 31.29s
# ---> Validation Summary (using final output): Loss: 1.8079, Acc: 30.89%, Time: 3.03s
# Validation accuracy improved (14.12% -> 30.89%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 6/100 ---
# Current Learning Rate: 0.100000
# Epoch [6/100], Step [97/391], Loss: 3.4895 (FinalCE: 1.8251, AuxCE: 3.7747, KD: 0.2576)
# Epoch [6/100], Step [194/391], Loss: 3.4555 (FinalCE: 1.8149, AuxCE: 3.7394, KD: 0.2414)
# Epoch [6/100], Step [291/391], Loss: 3.4275 (FinalCE: 1.8024, AuxCE: 3.7071, KD: 0.2372)
# Epoch [6/100], Step [388/391], Loss: 3.3940 (FinalCE: 1.7896, AuxCE: 3.6751, KD: 0.2241)
# Epoch [6/100], Step [391/391], Loss: 3.3932 (FinalCE: 1.7892, AuxCE: 3.6744, KD: 0.2238)
# ---> Epoch 6 Training Summary: Avg Loss: 3.3932, Final Acc: 31.71%, Time: 29.25s
# ---> Validation Summary (using final output): Loss: 1.7004, Acc: 35.34%, Time: 2.51s
# Validation accuracy improved (30.89% -> 35.34%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 7/100 ---
# Current Learning Rate: 0.100000
# Epoch [7/100], Step [97/391], Loss: 3.2479 (FinalCE: 1.7315, AuxCE: 3.5242, KD: 0.1778)
# Epoch [7/100], Step [194/391], Loss: 3.2110 (FinalCE: 1.7160, AuxCE: 3.4774, KD: 0.1734)
# Epoch [7/100], Step [291/391], Loss: 3.1786 (FinalCE: 1.7019, AuxCE: 3.4382, KD: 0.1691)
# Epoch [7/100], Step [388/391], Loss: 3.1526 (FinalCE: 1.6901, AuxCE: 3.4086, KD: 0.1650)
# Epoch [7/100], Step [391/391], Loss: 3.1530 (FinalCE: 1.6906, AuxCE: 3.4091, KD: 0.1647)
# ---> Epoch 7 Training Summary: Avg Loss: 3.1530, Final Acc: 36.45%, Time: 29.19s
# ---> Validation Summary (using final output): Loss: 1.6889, Acc: 38.74%, Time: 3.04s
# Validation accuracy improved (35.34% -> 38.74%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 8/100 ---
# Current Learning Rate: 0.100000
# Epoch [8/100], Step [97/391], Loss: 3.0108 (FinalCE: 1.6174, AuxCE: 3.2500, KD: 0.1556)
# Epoch [8/100], Step [194/391], Loss: 2.9953 (FinalCE: 1.6067, AuxCE: 3.2299, KD: 0.1610)
# Epoch [8/100], Step [291/391], Loss: 2.9782 (FinalCE: 1.5972, AuxCE: 3.2061, KD: 0.1643)
# Epoch [8/100], Step [388/391], Loss: 2.9656 (FinalCE: 1.5919, AuxCE: 3.1914, KD: 0.1620)
# Epoch [8/100], Step [391/391], Loss: 2.9659 (FinalCE: 1.5921, AuxCE: 3.1914, KD: 0.1621)
# ---> Epoch 8 Training Summary: Avg Loss: 2.9659, Final Acc: 41.05%, Time: 29.92s
# ---> Validation Summary (using final output): Loss: 1.5795, Acc: 43.07%, Time: 2.50s
# Validation accuracy improved (38.74% -> 43.07%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 9/100 ---
# Current Learning Rate: 0.100000
# Epoch [9/100], Step [97/391], Loss: 2.8533 (FinalCE: 1.5378, AuxCE: 3.0612, KD: 0.1518)
# Epoch [9/100], Step [194/391], Loss: 2.8406 (FinalCE: 1.5292, AuxCE: 3.0451, KD: 0.1556)
# Epoch [9/100], Step [291/391], Loss: 2.8307 (FinalCE: 1.5248, AuxCE: 3.0328, KD: 0.1547)
# Epoch [9/100], Step [388/391], Loss: 2.8053 (FinalCE: 1.5116, AuxCE: 3.0081, KD: 0.1508)
# Epoch [9/100], Step [391/391], Loss: 2.8041 (FinalCE: 1.5109, AuxCE: 3.0069, KD: 0.1507)
# ---> Epoch 9 Training Summary: Avg Loss: 2.8041, Final Acc: 44.59%, Time: 29.15s
# ---> Validation Summary (using final output): Loss: 1.4715, Acc: 47.10%, Time: 2.53s
# Validation accuracy improved (43.07% -> 47.10%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 10/100 ---
# Current Learning Rate: 0.100000
# Epoch [10/100], Step [97/391], Loss: 2.6970 (FinalCE: 1.4548, AuxCE: 2.8933, KD: 0.1414)
# Epoch [10/100], Step [194/391], Loss: 2.6895 (FinalCE: 1.4525, AuxCE: 2.8798, KD: 0.1416)
# Epoch [10/100], Step [291/391], Loss: 2.6712 (FinalCE: 1.4429, AuxCE: 2.8578, KD: 0.1419)
# Epoch [10/100], Step [388/391], Loss: 2.6516 (FinalCE: 1.4327, AuxCE: 2.8315, KD: 0.1438)
# Epoch [10/100], Step [391/391], Loss: 2.6518 (FinalCE: 1.4328, AuxCE: 2.8317, KD: 0.1438)
# ---> Epoch 10 Training Summary: Avg Loss: 2.6518, Final Acc: 47.98%, Time: 29.46s
# ---> Validation Summary (using final output): Loss: 1.4006, Acc: 48.83%, Time: 3.64s
# Validation accuracy improved (47.10% -> 48.83%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 11/100 ---
# Current Learning Rate: 0.100000
# Epoch [11/100], Step [97/391], Loss: 2.5481 (FinalCE: 1.3745, AuxCE: 2.7093, KD: 0.1499)
# Epoch [11/100], Step [194/391], Loss: 2.5307 (FinalCE: 1.3677, AuxCE: 2.6886, KD: 0.1460)
# Epoch [11/100], Step [291/391], Loss: 2.5146 (FinalCE: 1.3588, AuxCE: 2.6691, KD: 0.1469)
# Epoch [11/100], Step [388/391], Loss: 2.5055 (FinalCE: 1.3533, AuxCE: 2.6578, KD: 0.1484)
# Epoch [11/100], Step [391/391], Loss: 2.5057 (FinalCE: 1.3535, AuxCE: 2.6580, KD: 0.1484)
# ---> Epoch 11 Training Summary: Avg Loss: 2.5057, Final Acc: 51.23%, Time: 29.36s
# ---> Validation Summary (using final output): Loss: 1.4761, Acc: 49.74%, Time: 2.54s
# Validation accuracy improved (48.83% -> 49.74%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 12/100 ---
# Current Learning Rate: 0.100000
# Epoch [12/100], Step [97/391], Loss: 2.4802 (FinalCE: 1.3367, AuxCE: 2.6190, KD: 0.1598)
# Epoch [12/100], Step [194/391], Loss: 2.4717 (FinalCE: 1.3332, AuxCE: 2.6117, KD: 0.1562)
# Epoch [12/100], Step [291/391], Loss: 2.4505 (FinalCE: 1.3220, AuxCE: 2.5877, KD: 0.1557)
# Epoch [12/100], Step [388/391], Loss: 2.4282 (FinalCE: 1.3091, AuxCE: 2.5618, KD: 0.1573)
# Epoch [12/100], Step [391/391], Loss: 2.4283 (FinalCE: 1.3090, AuxCE: 2.5622, KD: 0.1574)
# ---> Epoch 12 Training Summary: Avg Loss: 2.4283, Final Acc: 52.98%, Time: 29.41s
# ---> Validation Summary (using final output): Loss: 1.3777, Acc: 51.84%, Time: 2.56s
# Validation accuracy improved (49.74% -> 51.84%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 13/100 ---
# Current Learning Rate: 0.100000
# Epoch [13/100], Step [97/391], Loss: 2.3527 (FinalCE: 1.2672, AuxCE: 2.4743, KD: 0.1596)
# Epoch [13/100], Step [194/391], Loss: 2.3568 (FinalCE: 1.2678, AuxCE: 2.4746, KD: 0.1653)
# Epoch [13/100], Step [291/391], Loss: 2.3491 (FinalCE: 1.2636, AuxCE: 2.4661, KD: 0.1651)
# Epoch [13/100], Step [388/391], Loss: 2.3263 (FinalCE: 1.2509, AuxCE: 2.4459, KD: 0.1617)
# Epoch [13/100], Step [391/391], Loss: 2.3274 (FinalCE: 1.2515, AuxCE: 2.4472, KD: 0.1618)
# ---> Epoch 13 Training Summary: Avg Loss: 2.3274, Final Acc: 55.71%, Time: 30.66s
# ---> Validation Summary (using final output): Loss: 1.2143, Acc: 57.68%, Time: 2.59s
# Validation accuracy improved (51.84% -> 57.68%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 14/100 ---
# Current Learning Rate: 0.100000
# Epoch [14/100], Step [97/391], Loss: 2.2883 (FinalCE: 1.2332, AuxCE: 2.4045, KD: 0.1555)
# Epoch [14/100], Step [194/391], Loss: 2.2743 (FinalCE: 1.2258, AuxCE: 2.3932, KD: 0.1521)
# Epoch [14/100], Step [291/391], Loss: 2.2588 (FinalCE: 1.2173, AuxCE: 2.3803, KD: 0.1489)
# Epoch [14/100], Step [388/391], Loss: 2.2483 (FinalCE: 1.2110, AuxCE: 2.3644, KD: 0.1526)
# Epoch [14/100], Step [391/391], Loss: 2.2466 (FinalCE: 1.2099, AuxCE: 2.3630, KD: 0.1525)
# ---> Epoch 14 Training Summary: Avg Loss: 2.2466, Final Acc: 56.96%, Time: 30.27s
# ---> Validation Summary (using final output): Loss: 1.2180, Acc: 58.93%, Time: 2.53s
# Validation accuracy improved (57.68% -> 58.93%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 15/100 ---
# Current Learning Rate: 0.100000
# Epoch [15/100], Step [97/391], Loss: 2.1721 (FinalCE: 1.1659, AuxCE: 2.2760, KD: 0.1596)
# Epoch [15/100], Step [194/391], Loss: 2.1694 (FinalCE: 1.1670, AuxCE: 2.2774, KD: 0.1524)
# Epoch [15/100], Step [291/391], Loss: 2.1787 (FinalCE: 1.1695, AuxCE: 2.2857, KD: 0.1582)
# Epoch [15/100], Step [388/391], Loss: 2.1707 (FinalCE: 1.1657, AuxCE: 2.2778, KD: 0.1565)
# Epoch [15/100], Step [391/391], Loss: 2.1727 (FinalCE: 1.1667, AuxCE: 2.2800, KD: 0.1566)
# ---> Epoch 15 Training Summary: Avg Loss: 2.1727, Final Acc: 58.99%, Time: 29.77s
# ---> Validation Summary (using final output): Loss: 1.2151, Acc: 58.81%, Time: 3.20s
#
# --- Epoch 16/100 ---
# Current Learning Rate: 0.100000
# Epoch [16/100], Step [97/391], Loss: 2.1383 (FinalCE: 1.1526, AuxCE: 2.2535, KD: 0.1406)
# Epoch [16/100], Step [194/391], Loss: 2.1372 (FinalCE: 1.1493, AuxCE: 2.2406, KD: 0.1529)
# Epoch [16/100], Step [291/391], Loss: 2.1372 (FinalCE: 1.1483, AuxCE: 2.2369, KD: 0.1569)
# Epoch [16/100], Step [388/391], Loss: 2.1247 (FinalCE: 1.1406, AuxCE: 2.2231, KD: 0.1581)
# Epoch [16/100], Step [391/391], Loss: 2.1256 (FinalCE: 1.1410, AuxCE: 2.2241, KD: 0.1582)
# ---> Epoch 16 Training Summary: Avg Loss: 2.1256, Final Acc: 59.90%, Time: 28.42s
# ---> Validation Summary (using final output): Loss: 1.2858, Acc: 54.68%, Time: 2.58s
#
# --- Epoch 17/100 ---
# Current Learning Rate: 0.100000
# Epoch [17/100], Step [97/391], Loss: 2.1096 (FinalCE: 1.1298, AuxCE: 2.2031, KD: 0.1642)
# Epoch [17/100], Step [194/391], Loss: 2.0966 (FinalCE: 1.1205, AuxCE: 2.1815, KD: 0.1724)
# Epoch [17/100], Step [291/391], Loss: 2.0832 (FinalCE: 1.1160, AuxCE: 2.1691, KD: 0.1659)
# Epoch [17/100], Step [388/391], Loss: 2.0740 (FinalCE: 1.1115, AuxCE: 2.1630, KD: 0.1622)
# Epoch [17/100], Step [391/391], Loss: 2.0741 (FinalCE: 1.1116, AuxCE: 2.1629, KD: 0.1623)
# ---> Epoch 17 Training Summary: Avg Loss: 2.0741, Final Acc: 61.06%, Time: 28.44s
# ---> Validation Summary (using final output): Loss: 1.4644, Acc: 52.43%, Time: 2.54s
#
# --- Epoch 18/100 ---
# Current Learning Rate: 0.100000
# Epoch [18/100], Step [97/391], Loss: 2.0366 (FinalCE: 1.0836, AuxCE: 2.1142, KD: 0.1787)
# Epoch [18/100], Step [194/391], Loss: 2.0600 (FinalCE: 1.0968, AuxCE: 2.1403, KD: 0.1785)
# Epoch [18/100], Step [291/391], Loss: 2.0307 (FinalCE: 1.0800, AuxCE: 2.1073, KD: 0.1796)
# Epoch [18/100], Step [388/391], Loss: 2.0220 (FinalCE: 1.0736, AuxCE: 2.0972, KD: 0.1825)
# Epoch [18/100], Step [391/391], Loss: 2.0208 (FinalCE: 1.0730, AuxCE: 2.0961, KD: 0.1823)
# ---> Epoch 18 Training Summary: Avg Loss: 2.0208, Final Acc: 62.93%, Time: 29.39s
# ---> Validation Summary (using final output): Loss: 1.4084, Acc: 52.97%, Time: 3.80s
#
# --- Epoch 19/100 ---
# Current Learning Rate: 0.100000
# Epoch [19/100], Step [97/391], Loss: 1.9615 (FinalCE: 1.0465, AuxCE: 2.0404, KD: 0.1648)
# Epoch [19/100], Step [194/391], Loss: 1.9687 (FinalCE: 1.0477, AuxCE: 2.0413, KD: 0.1742)
# Epoch [19/100], Step [291/391], Loss: 1.9672 (FinalCE: 1.0438, AuxCE: 2.0340, KD: 0.1830)
# Epoch [19/100], Step [388/391], Loss: 1.9671 (FinalCE: 1.0430, AuxCE: 2.0325, KD: 0.1851)
# Epoch [19/100], Step [391/391], Loss: 1.9691 (FinalCE: 1.0442, AuxCE: 2.0345, KD: 0.1852)
# ---> Epoch 19 Training Summary: Avg Loss: 1.9691, Final Acc: 63.93%, Time: 28.49s
# ---> Validation Summary (using final output): Loss: 1.2438, Acc: 57.60%, Time: 2.56s
#
# --- Epoch 20/100 ---
# Current Learning Rate: 0.100000
# Epoch [20/100], Step [97/391], Loss: 1.9314 (FinalCE: 1.0147, AuxCE: 1.9706, KD: 0.2142)
# Epoch [20/100], Step [194/391], Loss: 1.9402 (FinalCE: 1.0211, AuxCE: 1.9804, KD: 0.2115)
# Epoch [20/100], Step [291/391], Loss: 1.9379 (FinalCE: 1.0237, AuxCE: 1.9864, KD: 0.1994)
# Epoch [20/100], Step [388/391], Loss: 1.9222 (FinalCE: 1.0148, AuxCE: 1.9692, KD: 0.1996)
# Epoch [20/100], Step [391/391], Loss: 1.9219 (FinalCE: 1.0145, AuxCE: 1.9690, KD: 0.1996)
# ---> Epoch 20 Training Summary: Avg Loss: 1.9219, Final Acc: 65.41%, Time: 28.39s
# ---> Validation Summary (using final output): Loss: 1.2335, Acc: 59.17%, Time: 2.54s
# Validation accuracy improved (58.93% -> 59.17%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 21/100 ---
# Current Learning Rate: 0.100000
# Epoch [21/100], Step [97/391], Loss: 1.8197 (FinalCE: 0.9671, AuxCE: 1.8816, KD: 0.1666)
# Epoch [21/100], Step [194/391], Loss: 1.8579 (FinalCE: 0.9774, AuxCE: 1.9149, KD: 0.1910)
# Epoch [21/100], Step [291/391], Loss: 1.8942 (FinalCE: 0.9914, AuxCE: 1.9436, KD: 0.2089)
# Epoch [21/100], Step [388/391], Loss: 1.8884 (FinalCE: 0.9909, AuxCE: 1.9367, KD: 0.2048)
# Epoch [21/100], Step [391/391], Loss: 1.8871 (FinalCE: 0.9903, AuxCE: 1.9351, KD: 0.2047)
# ---> Epoch 21 Training Summary: Avg Loss: 1.8871, Final Acc: 66.16%, Time: 29.26s
# ---> Validation Summary (using final output): Loss: 1.2575, Acc: 58.35%, Time: 3.74s
#
# --- Epoch 22/100 ---
# Current Learning Rate: 0.100000
# Epoch [22/100], Step [97/391], Loss: 1.8480 (FinalCE: 0.9745, AuxCE: 1.8884, KD: 0.1969)
# Epoch [22/100], Step [194/391], Loss: 1.8376 (FinalCE: 0.9601, AuxCE: 1.8751, KD: 0.2125)
# Epoch [22/100], Step [291/391], Loss: 1.8454 (FinalCE: 0.9660, AuxCE: 1.8868, KD: 0.2079)
# Epoch [22/100], Step [388/391], Loss: 1.8453 (FinalCE: 0.9651, AuxCE: 1.8869, KD: 0.2092)
# Epoch [22/100], Step [391/391], Loss: 1.8456 (FinalCE: 0.9651, AuxCE: 1.8872, KD: 0.2093)
# ---> Epoch 22 Training Summary: Avg Loss: 1.8456, Final Acc: 66.93%, Time: 29.34s
# ---> Validation Summary (using final output): Loss: 1.0163, Acc: 65.25%, Time: 2.52s
# Validation accuracy improved (59.17% -> 65.25%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 23/100 ---
# Current Learning Rate: 0.100000
# Epoch [23/100], Step [97/391], Loss: 1.8466 (FinalCE: 0.9718, AuxCE: 1.8678, KD: 0.2128)
# Epoch [23/100], Step [194/391], Loss: 1.8495 (FinalCE: 0.9662, AuxCE: 1.8770, KD: 0.2209)
# Epoch [23/100], Step [291/391], Loss: 1.8529 (FinalCE: 0.9633, AuxCE: 1.8812, KD: 0.2285)
# Epoch [23/100], Step [388/391], Loss: 1.8602 (FinalCE: 0.9673, AuxCE: 1.8869, KD: 0.2302)
# Epoch [23/100], Step [391/391], Loss: 1.8597 (FinalCE: 0.9671, AuxCE: 1.8868, KD: 0.2298)
# ---> Epoch 23 Training Summary: Avg Loss: 1.8597, Final Acc: 67.34%, Time: 29.38s
# ---> Validation Summary (using final output): Loss: 1.1670, Acc: 63.65%, Time: 2.52s
#
# --- Epoch 24/100 ---
# Current Learning Rate: 0.100000
# Epoch [24/100], Step [97/391], Loss: 1.7795 (FinalCE: 0.9343, AuxCE: 1.8176, KD: 0.1969)
# Epoch [24/100], Step [194/391], Loss: 1.7724 (FinalCE: 0.9306, AuxCE: 1.8093, KD: 0.1968)
# Epoch [24/100], Step [291/391], Loss: 1.7761 (FinalCE: 0.9309, AuxCE: 1.8109, KD: 0.2013)
# Epoch [24/100], Step [388/391], Loss: 1.7803 (FinalCE: 0.9327, AuxCE: 1.8174, KD: 0.2010)
# Epoch [24/100], Step [391/391], Loss: 1.7790 (FinalCE: 0.9320, AuxCE: 1.8156, KD: 0.2012)
# ---> Epoch 24 Training Summary: Avg Loss: 1.7790, Final Acc: 68.51%, Time: 28.34s
# ---> Validation Summary (using final output): Loss: 1.1572, Acc: 63.81%, Time: 3.78s
#
# --- Epoch 25/100 ---
# Current Learning Rate: 0.100000
# Epoch [25/100], Step [97/391], Loss: 1.8028 (FinalCE: 0.9320, AuxCE: 1.8237, KD: 0.2355)
# Epoch [25/100], Step [194/391], Loss: 1.7852 (FinalCE: 0.9240, AuxCE: 1.8031, KD: 0.2334)
# Epoch [25/100], Step [291/391], Loss: 1.7727 (FinalCE: 0.9201, AuxCE: 1.7897, KD: 0.2279)
# Epoch [25/100], Step [388/391], Loss: 1.7837 (FinalCE: 0.9245, AuxCE: 1.7987, KD: 0.2329)
# Epoch [25/100], Step [391/391], Loss: 1.7836 (FinalCE: 0.9243, AuxCE: 1.7991, KD: 0.2329)
# ---> Epoch 25 Training Summary: Avg Loss: 1.7836, Final Acc: 68.76%, Time: 28.41s
# ---> Validation Summary (using final output): Loss: 1.6631, Acc: 56.58%, Time: 2.51s
#
# --- Epoch 26/100 ---
# Current Learning Rate: 0.100000
# Epoch [26/100], Step [97/391], Loss: 1.8073 (FinalCE: 0.9322, AuxCE: 1.8196, KD: 0.2456)
# Epoch [26/100], Step [194/391], Loss: 1.7703 (FinalCE: 0.9098, AuxCE: 1.7807, KD: 0.2470)
# Epoch [26/100], Step [291/391], Loss: 1.7709 (FinalCE: 0.9130, AuxCE: 1.7835, KD: 0.2409)
# Epoch [26/100], Step [388/391], Loss: 1.7774 (FinalCE: 0.9177, AuxCE: 1.7924, KD: 0.2380)
# Epoch [26/100], Step [391/391], Loss: 1.7785 (FinalCE: 0.9181, AuxCE: 1.7938, KD: 0.2382)
# ---> Epoch 26 Training Summary: Avg Loss: 1.7785, Final Acc: 69.14%, Time: 28.36s
# ---> Validation Summary (using final output): Loss: 1.1355, Acc: 62.93%, Time: 3.12s
#
# --- Epoch 27/100 ---
# Current Learning Rate: 0.100000
# Epoch [27/100], Step [97/391], Loss: 1.7126 (FinalCE: 0.8915, AuxCE: 1.7253, KD: 0.2181)
# Epoch [27/100], Step [194/391], Loss: 1.6979 (FinalCE: 0.8853, AuxCE: 1.7195, KD: 0.2079)
# Epoch [27/100], Step [291/391], Loss: 1.7013 (FinalCE: 0.8864, AuxCE: 1.7195, KD: 0.2120)
# Epoch [27/100], Step [388/391], Loss: 1.7275 (FinalCE: 0.8943, AuxCE: 1.7389, KD: 0.2294)
# Epoch [27/100], Step [391/391], Loss: 1.7286 (FinalCE: 0.8949, AuxCE: 1.7404, KD: 0.2293)
# ---> Epoch 27 Training Summary: Avg Loss: 1.7286, Final Acc: 69.78%, Time: 28.85s
# ---> Validation Summary (using final output): Loss: 1.0947, Acc: 63.30%, Time: 3.10s
#
# --- Epoch 28/100 ---
# Current Learning Rate: 0.100000
# Epoch [28/100], Step [97/391], Loss: 1.7400 (FinalCE: 0.8975, AuxCE: 1.7402, KD: 0.2441)
# Epoch [28/100], Step [194/391], Loss: 1.7163 (FinalCE: 0.8878, AuxCE: 1.7224, KD: 0.2326)
# Epoch [28/100], Step [291/391], Loss: 1.7131 (FinalCE: 0.8905, AuxCE: 1.7253, KD: 0.2209)
# Epoch [28/100], Step [388/391], Loss: 1.7295 (FinalCE: 0.8951, AuxCE: 1.7387, KD: 0.2315)
# Epoch [28/100], Step [391/391], Loss: 1.7282 (FinalCE: 0.8942, AuxCE: 1.7373, KD: 0.2318)
# ---> Epoch 28 Training Summary: Avg Loss: 1.7282, Final Acc: 69.65%, Time: 28.76s
# ---> Validation Summary (using final output): Loss: 1.0104, Acc: 67.07%, Time: 2.75s
# Validation accuracy improved (65.25% -> 67.07%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 29/100 ---
# Current Learning Rate: 0.100000
# Epoch [29/100], Step [97/391], Loss: 1.7084 (FinalCE: 0.8859, AuxCE: 1.7193, KD: 0.2246)
# Epoch [29/100], Step [194/391], Loss: 1.7180 (FinalCE: 0.8906, AuxCE: 1.7304, KD: 0.2255)
# Epoch [29/100], Step [291/391], Loss: 1.7013 (FinalCE: 0.8804, AuxCE: 1.7091, KD: 0.2288)
# Epoch [29/100], Step [388/391], Loss: 1.7183 (FinalCE: 0.8861, AuxCE: 1.7207, KD: 0.2399)
# Epoch [29/100], Step [391/391], Loss: 1.7187 (FinalCE: 0.8864, AuxCE: 1.7216, KD: 0.2395)
# ---> Epoch 29 Training Summary: Avg Loss: 1.7187, Final Acc: 70.09%, Time: 29.40s
# ---> Validation Summary (using final output): Loss: 0.9276, Acc: 68.39%, Time: 2.50s
# Validation accuracy improved (67.07% -> 68.39%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 30/100 ---
# Current Learning Rate: 0.100000
# Epoch [30/100], Step [97/391], Loss: 1.6535 (FinalCE: 0.8529, AuxCE: 1.6567, KD: 0.2299)
# Epoch [30/100], Step [194/391], Loss: 1.6946 (FinalCE: 0.8700, AuxCE: 1.6953, KD: 0.2442)
# Epoch [30/100], Step [291/391], Loss: 1.6975 (FinalCE: 0.8724, AuxCE: 1.7009, KD: 0.2412)
# Epoch [30/100], Step [388/391], Loss: 1.6949 (FinalCE: 0.8718, AuxCE: 1.6985, KD: 0.2395)
# Epoch [30/100], Step [391/391], Loss: 1.6951 (FinalCE: 0.8718, AuxCE: 1.6991, KD: 0.2394)
# ---> Epoch 30 Training Summary: Avg Loss: 1.6951, Final Acc: 70.59%, Time: 29.42s
# ---> Validation Summary (using final output): Loss: 0.9665, Acc: 68.29%, Time: 3.58s
#
# --- Epoch 31/100 ---
# Current Learning Rate: 0.100000
# Epoch [31/100], Step [97/391], Loss: 1.6927 (FinalCE: 0.8587, AuxCE: 1.6796, KD: 0.2703)
# Epoch [31/100], Step [194/391], Loss: 1.6753 (FinalCE: 0.8577, AuxCE: 1.6689, KD: 0.2500)
# Epoch [31/100], Step [291/391], Loss: 1.7066 (FinalCE: 0.8714, AuxCE: 1.6981, KD: 0.2601)
# Epoch [31/100], Step [388/391], Loss: 1.7043 (FinalCE: 0.8703, AuxCE: 1.6953, KD: 0.2599)
# Epoch [31/100], Step [391/391], Loss: 1.7056 (FinalCE: 0.8713, AuxCE: 1.6969, KD: 0.2593)
# ---> Epoch 31 Training Summary: Avg Loss: 1.7056, Final Acc: 70.91%, Time: 29.76s
# ---> Validation Summary (using final output): Loss: 1.0181, Acc: 65.87%, Time: 2.50s
#
# --- Epoch 32/100 ---
# Current Learning Rate: 0.100000
# Epoch [32/100], Step [97/391], Loss: 1.6947 (FinalCE: 0.8665, AuxCE: 1.6759, KD: 0.2631)
# Epoch [32/100], Step [194/391], Loss: 1.6640 (FinalCE: 0.8528, AuxCE: 1.6510, KD: 0.2513)
# Epoch [32/100], Step [291/391], Loss: 1.6546 (FinalCE: 0.8498, AuxCE: 1.6435, KD: 0.2457)
# Epoch [32/100], Step [388/391], Loss: 1.6607 (FinalCE: 0.8535, AuxCE: 1.6541, KD: 0.2426)
# Epoch [32/100], Step [391/391], Loss: 1.6600 (FinalCE: 0.8529, AuxCE: 1.6531, KD: 0.2431)
# ---> Epoch 32 Training Summary: Avg Loss: 1.6600, Final Acc: 71.33%, Time: 28.40s
# ---> Validation Summary (using final output): Loss: 0.9400, Acc: 69.42%, Time: 2.51s
# Validation accuracy improved (68.39% -> 69.42%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 33/100 ---
# Current Learning Rate: 0.100000
# Epoch [33/100], Step [97/391], Loss: 1.6975 (FinalCE: 0.8580, AuxCE: 1.6795, KD: 0.2795)
# Epoch [33/100], Step [194/391], Loss: 1.6761 (FinalCE: 0.8521, AuxCE: 1.6644, KD: 0.2638)
# Epoch [33/100], Step [291/391], Loss: 1.6750 (FinalCE: 0.8552, AuxCE: 1.6678, KD: 0.2545)
# Epoch [33/100], Step [388/391], Loss: 1.6875 (FinalCE: 0.8591, AuxCE: 1.6783, KD: 0.2618)
# Epoch [33/100], Step [391/391], Loss: 1.6869 (FinalCE: 0.8586, AuxCE: 1.6776, KD: 0.2620)
# ---> Epoch 33 Training Summary: Avg Loss: 1.6869, Final Acc: 71.31%, Time: 29.24s
# ---> Validation Summary (using final output): Loss: 1.1138, Acc: 65.89%, Time: 3.17s
#
# --- Epoch 34/100 ---
# Current Learning Rate: 0.100000
# Epoch [34/100], Step [97/391], Loss: 1.6312 (FinalCE: 0.8376, AuxCE: 1.6247, KD: 0.2396)
# Epoch [34/100], Step [194/391], Loss: 1.6815 (FinalCE: 0.8601, AuxCE: 1.6683, KD: 0.2569)
# Epoch [34/100], Step [291/391], Loss: 1.6583 (FinalCE: 0.8482, AuxCE: 1.6491, KD: 0.2508)
# Epoch [34/100], Step [388/391], Loss: 1.6564 (FinalCE: 0.8473, AuxCE: 1.6468, KD: 0.2507)
# Epoch [34/100], Step [391/391], Loss: 1.6564 (FinalCE: 0.8473, AuxCE: 1.6472, KD: 0.2504)
# ---> Epoch 34 Training Summary: Avg Loss: 1.6564, Final Acc: 71.57%, Time: 28.57s
# ---> Validation Summary (using final output): Loss: 1.1362, Acc: 65.53%, Time: 2.50s
#
# --- Epoch 35/100 ---
# Current Learning Rate: 0.100000
# Epoch [35/100], Step [97/391], Loss: 1.6909 (FinalCE: 0.8513, AuxCE: 1.6524, KD: 0.2977)
# Epoch [35/100], Step [194/391], Loss: 1.7011 (FinalCE: 0.8506, AuxCE: 1.6686, KD: 0.3050)
# Epoch [35/100], Step [291/391], Loss: 1.7073 (FinalCE: 0.8544, AuxCE: 1.6747, KD: 0.3052)
# Epoch [35/100], Step [388/391], Loss: 1.7059 (FinalCE: 0.8555, AuxCE: 1.6737, KD: 0.3015)
# Epoch [35/100], Step [391/391], Loss: 1.7052 (FinalCE: 0.8550, AuxCE: 1.6731, KD: 0.3015)
# ---> Epoch 35 Training Summary: Avg Loss: 1.7052, Final Acc: 71.30%, Time: 29.52s
# ---> Validation Summary (using final output): Loss: 0.9329, Acc: 70.41%, Time: 2.52s
# Validation accuracy improved (69.42% -> 70.41%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 36/100 ---
# Current Learning Rate: 0.100000
# Epoch [36/100], Step [97/391], Loss: 1.5984 (FinalCE: 0.8217, AuxCE: 1.5949, KD: 0.2312)
# Epoch [36/100], Step [194/391], Loss: 1.6029 (FinalCE: 0.8263, AuxCE: 1.6012, KD: 0.2267)
# Epoch [36/100], Step [291/391], Loss: 1.6175 (FinalCE: 0.8292, AuxCE: 1.6088, KD: 0.2414)
# Epoch [36/100], Step [388/391], Loss: 1.6297 (FinalCE: 0.8319, AuxCE: 1.6169, KD: 0.2517)
# Epoch [36/100], Step [391/391], Loss: 1.6289 (FinalCE: 0.8315, AuxCE: 1.6160, KD: 0.2516)
# ---> Epoch 36 Training Summary: Avg Loss: 1.6289, Final Acc: 72.10%, Time: 29.18s
# ---> Validation Summary (using final output): Loss: 1.1713, Acc: 65.02%, Time: 2.80s
#
# --- Epoch 37/100 ---
# Current Learning Rate: 0.100000
# Epoch [37/100], Step [97/391], Loss: 1.6504 (FinalCE: 0.8282, AuxCE: 1.5998, KD: 0.3037)
# Epoch [37/100], Step [194/391], Loss: 1.6388 (FinalCE: 0.8291, AuxCE: 1.6058, KD: 0.2790)
# Epoch [37/100], Step [291/391], Loss: 1.6492 (FinalCE: 0.8334, AuxCE: 1.6172, KD: 0.2816)
# Epoch [37/100], Step [388/391], Loss: 1.6677 (FinalCE: 0.8420, AuxCE: 1.6409, KD: 0.2824)
# Epoch [37/100], Step [391/391], Loss: 1.6674 (FinalCE: 0.8415, AuxCE: 1.6403, KD: 0.2830)
# ---> Epoch 37 Training Summary: Avg Loss: 1.6674, Final Acc: 71.71%, Time: 28.38s
# ---> Validation Summary (using final output): Loss: 0.9015, Acc: 70.42%, Time: 3.14s
# Validation accuracy improved (70.41% -> 70.42%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 38/100 ---
# Current Learning Rate: 0.100000
# Epoch [38/100], Step [97/391], Loss: 1.6099 (FinalCE: 0.8231, AuxCE: 1.5816, KD: 0.2570)
# Epoch [38/100], Step [194/391], Loss: 1.6134 (FinalCE: 0.8256, AuxCE: 1.5885, KD: 0.2541)
# Epoch [38/100], Step [291/391], Loss: 1.6110 (FinalCE: 0.8207, AuxCE: 1.5891, KD: 0.2578)
# Epoch [38/100], Step [388/391], Loss: 1.6178 (FinalCE: 0.8261, AuxCE: 1.6030, KD: 0.2509)
# Epoch [38/100], Step [391/391], Loss: 1.6171 (FinalCE: 0.8256, AuxCE: 1.6026, KD: 0.2507)
# ---> Epoch 38 Training Summary: Avg Loss: 1.6171, Final Acc: 72.38%, Time: 29.40s
# ---> Validation Summary (using final output): Loss: 1.0333, Acc: 66.65%, Time: 2.53s
#
# --- Epoch 39/100 ---
# Current Learning Rate: 0.100000
# Epoch [39/100], Step [97/391], Loss: 1.6347 (FinalCE: 0.8193, AuxCE: 1.6152, KD: 0.2823)
# Epoch [39/100], Step [194/391], Loss: 1.6233 (FinalCE: 0.8208, AuxCE: 1.6069, KD: 0.2662)
# Epoch [39/100], Step [291/391], Loss: 1.6180 (FinalCE: 0.8184, AuxCE: 1.5998, KD: 0.2661)
# Epoch [39/100], Step [388/391], Loss: 1.6406 (FinalCE: 0.8285, AuxCE: 1.6195, KD: 0.2739)
# Epoch [39/100], Step [391/391], Loss: 1.6402 (FinalCE: 0.8283, AuxCE: 1.6195, KD: 0.2735)
# ---> Epoch 39 Training Summary: Avg Loss: 1.6402, Final Acc: 72.32%, Time: 28.45s
# ---> Validation Summary (using final output): Loss: 1.1957, Acc: 64.23%, Time: 3.64s
#
# --- Epoch 40/100 ---
# Current Learning Rate: 0.100000
# Epoch [40/100], Step [97/391], Loss: 1.6296 (FinalCE: 0.8296, AuxCE: 1.6003, KD: 0.2665)
# Epoch [40/100], Step [194/391], Loss: 1.6000 (FinalCE: 0.8158, AuxCE: 1.5793, KD: 0.2541)
# Epoch [40/100], Step [291/391], Loss: 1.6050 (FinalCE: 0.8190, AuxCE: 1.5833, KD: 0.2546)
# Epoch [40/100], Step [388/391], Loss: 1.6228 (FinalCE: 0.8271, AuxCE: 1.5966, KD: 0.2619)
# Epoch [40/100], Step [391/391], Loss: 1.6214 (FinalCE: 0.8264, AuxCE: 1.5950, KD: 0.2617)
# ---> Epoch 40 Training Summary: Avg Loss: 1.6214, Final Acc: 72.58%, Time: 29.05s
# ---> Validation Summary (using final output): Loss: 1.0299, Acc: 67.44%, Time: 3.27s
#
# --- Epoch 41/100 ---
# Current Learning Rate: 0.100000
# Epoch [41/100], Step [97/391], Loss: 1.6380 (FinalCE: 0.8317, AuxCE: 1.6129, KD: 0.2686)
# Epoch [41/100], Step [194/391], Loss: 1.6303 (FinalCE: 0.8264, AuxCE: 1.6047, KD: 0.2700)
# Epoch [41/100], Step [291/391], Loss: 1.6293 (FinalCE: 0.8251, AuxCE: 1.6024, KD: 0.2719)
# Epoch [41/100], Step [388/391], Loss: 1.6186 (FinalCE: 0.8213, AuxCE: 1.5944, KD: 0.2660)
# Epoch [41/100], Step [391/391], Loss: 1.6188 (FinalCE: 0.8215, AuxCE: 1.5947, KD: 0.2655)
# ---> Epoch 41 Training Summary: Avg Loss: 1.6188, Final Acc: 72.58%, Time: 28.33s
# ---> Validation Summary (using final output): Loss: 1.0078, Acc: 68.14%, Time: 2.62s
#
# --- Epoch 42/100 ---
# Current Learning Rate: 0.100000
# Epoch [42/100], Step [97/391], Loss: 1.5454 (FinalCE: 0.7881, AuxCE: 1.5172, KD: 0.2507)
# Epoch [42/100], Step [194/391], Loss: 1.5612 (FinalCE: 0.7987, AuxCE: 1.5417, KD: 0.2429)
# Epoch [42/100], Step [291/391], Loss: 1.5902 (FinalCE: 0.8082, AuxCE: 1.5672, KD: 0.2585)
# Epoch [42/100], Step [388/391], Loss: 1.5985 (FinalCE: 0.8127, AuxCE: 1.5739, KD: 0.2604)
# Epoch [42/100], Step [391/391], Loss: 1.5983 (FinalCE: 0.8124, AuxCE: 1.5733, KD: 0.2608)
# ---> Epoch 42 Training Summary: Avg Loss: 1.5983, Final Acc: 72.98%, Time: 28.46s
# ---> Validation Summary (using final output): Loss: 1.0572, Acc: 65.43%, Time: 2.60s
#
# --- Epoch 43/100 ---
# Current Learning Rate: 0.100000
# Epoch [43/100], Step [97/391], Loss: 1.6180 (FinalCE: 0.8297, AuxCE: 1.5950, KD: 0.2504)
# Epoch [43/100], Step [194/391], Loss: 1.6135 (FinalCE: 0.8197, AuxCE: 1.5887, KD: 0.2640)
# Epoch [43/100], Step [291/391], Loss: 1.6408 (FinalCE: 0.8244, AuxCE: 1.6053, KD: 0.2905)
# Epoch [43/100], Step [388/391], Loss: 1.6320 (FinalCE: 0.8182, AuxCE: 1.5964, KD: 0.2920)
# Epoch [43/100], Step [391/391], Loss: 1.6326 (FinalCE: 0.8186, AuxCE: 1.5966, KD: 0.2923)
# ---> Epoch 43 Training Summary: Avg Loss: 1.6326, Final Acc: 72.68%, Time: 28.27s
# ---> Validation Summary (using final output): Loss: 1.2685, Acc: 62.97%, Time: 3.38s
#
# --- Epoch 44/100 ---
# Current Learning Rate: 0.100000
# Epoch [44/100], Step [97/391], Loss: 1.6736 (FinalCE: 0.8243, AuxCE: 1.6188, KD: 0.3363)
# Epoch [44/100], Step [194/391], Loss: 1.6218 (FinalCE: 0.8175, AuxCE: 1.5891, KD: 0.2811)
# Epoch [44/100], Step [291/391], Loss: 1.6052 (FinalCE: 0.8101, AuxCE: 1.5749, KD: 0.2752)
# Epoch [44/100], Step [388/391], Loss: 1.5981 (FinalCE: 0.8063, AuxCE: 1.5687, KD: 0.2739)
# Epoch [44/100], Step [391/391], Loss: 1.5987 (FinalCE: 0.8065, AuxCE: 1.5695, KD: 0.2741)
# ---> Epoch 44 Training Summary: Avg Loss: 1.5987, Final Acc: 73.08%, Time: 29.46s
# ---> Validation Summary (using final output): Loss: 0.9227, Acc: 71.03%, Time: 3.06s
# Validation accuracy improved (70.42% -> 71.03%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 45/100 ---
# Current Learning Rate: 0.100000
# Epoch [45/100], Step [97/391], Loss: 1.5556 (FinalCE: 0.7889, AuxCE: 1.5248, KD: 0.2613)
# Epoch [45/100], Step [194/391], Loss: 1.5979 (FinalCE: 0.8045, AuxCE: 1.5616, KD: 0.2814)
# Epoch [45/100], Step [291/391], Loss: 1.5848 (FinalCE: 0.8037, AuxCE: 1.5578, KD: 0.2634)
# Epoch [45/100], Step [388/391], Loss: 1.5836 (FinalCE: 0.8010, AuxCE: 1.5556, KD: 0.2672)
# Epoch [45/100], Step [391/391], Loss: 1.5847 (FinalCE: 0.8016, AuxCE: 1.5562, KD: 0.2678)
# ---> Epoch 45 Training Summary: Avg Loss: 1.5847, Final Acc: 73.42%, Time: 29.59s
# ---> Validation Summary (using final output): Loss: 0.8914, Acc: 69.75%, Time: 2.56s
#
# --- Epoch 46/100 ---
# Current Learning Rate: 0.100000
# Epoch [46/100], Step [97/391], Loss: 1.5670 (FinalCE: 0.7914, AuxCE: 1.5425, KD: 0.2644)
# Epoch [46/100], Step [194/391], Loss: 1.5588 (FinalCE: 0.7845, AuxCE: 1.5254, KD: 0.2737)
# Epoch [46/100], Step [291/391], Loss: 1.5659 (FinalCE: 0.7887, AuxCE: 1.5338, KD: 0.2729)
# Epoch [46/100], Step [388/391], Loss: 1.5738 (FinalCE: 0.7961, AuxCE: 1.5464, KD: 0.2652)
# Epoch [46/100], Step [391/391], Loss: 1.5741 (FinalCE: 0.7960, AuxCE: 1.5465, KD: 0.2658)
# ---> Epoch 46 Training Summary: Avg Loss: 1.5741, Final Acc: 73.41%, Time: 28.16s
# ---> Validation Summary (using final output): Loss: 1.0960, Acc: 67.75%, Time: 2.68s
#
# --- Epoch 47/100 ---
# Current Learning Rate: 0.100000
# Epoch [47/100], Step [97/391], Loss: 1.5721 (FinalCE: 0.7958, AuxCE: 1.5424, KD: 0.2654)
# Epoch [47/100], Step [194/391], Loss: 1.6316 (FinalCE: 0.8074, AuxCE: 1.5878, KD: 0.3152)
# Epoch [47/100], Step [291/391], Loss: 1.6026 (FinalCE: 0.8015, AuxCE: 1.5693, KD: 0.2890)
# Epoch [47/100], Step [388/391], Loss: 1.6037 (FinalCE: 0.8021, AuxCE: 1.5717, KD: 0.2882)
# Epoch [47/100], Step [391/391], Loss: 1.6046 (FinalCE: 0.8024, AuxCE: 1.5730, KD: 0.2883)
# ---> Epoch 47 Training Summary: Avg Loss: 1.6046, Final Acc: 73.13%, Time: 28.78s
# ---> Validation Summary (using final output): Loss: 0.8556, Acc: 72.85%, Time: 3.45s
# Validation accuracy improved (71.03% -> 72.85%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 48/100 ---
# Current Learning Rate: 0.100000
# Epoch [48/100], Step [97/391], Loss: 1.6207 (FinalCE: 0.8024, AuxCE: 1.5676, KD: 0.3187)
# Epoch [48/100], Step [194/391], Loss: 1.5943 (FinalCE: 0.7992, AuxCE: 1.5541, KD: 0.2891)
# Epoch [48/100], Step [291/391], Loss: 1.6012 (FinalCE: 0.8034, AuxCE: 1.5635, KD: 0.2873)
# Epoch [48/100], Step [388/391], Loss: 1.6163 (FinalCE: 0.8081, AuxCE: 1.5736, KD: 0.2980)
# Epoch [48/100], Step [391/391], Loss: 1.6175 (FinalCE: 0.8083, AuxCE: 1.5753, KD: 0.2985)
# ---> Epoch 48 Training Summary: Avg Loss: 1.6175, Final Acc: 73.01%, Time: 32.28s
# ---> Validation Summary (using final output): Loss: 0.9129, Acc: 69.90%, Time: 2.66s
#
# --- Epoch 49/100 ---
# Current Learning Rate: 0.100000
# Epoch [49/100], Step [97/391], Loss: 1.6582 (FinalCE: 0.8220, AuxCE: 1.6141, KD: 0.3174)
# Epoch [49/100], Step [194/391], Loss: 1.6015 (FinalCE: 0.8031, AuxCE: 1.5611, KD: 0.2900)
# Epoch [49/100], Step [291/391], Loss: 1.5892 (FinalCE: 0.7992, AuxCE: 1.5538, KD: 0.2808)
# Epoch [49/100], Step [388/391], Loss: 1.5878 (FinalCE: 0.7973, AuxCE: 1.5494, KD: 0.2846)
# Epoch [49/100], Step [391/391], Loss: 1.5880 (FinalCE: 0.7976, AuxCE: 1.5500, KD: 0.2840)
# ---> Epoch 49 Training Summary: Avg Loss: 1.5880, Final Acc: 73.66%, Time: 29.49s
# ---> Validation Summary (using final output): Loss: 1.0583, Acc: 68.28%, Time: 3.42s
#
# --- Epoch 50/100 ---
# Current Learning Rate: 0.100000
# Epoch [50/100], Step [97/391], Loss: 1.5524 (FinalCE: 0.7829, AuxCE: 1.5160, KD: 0.2719)
# Epoch [50/100], Step [194/391], Loss: 1.5922 (FinalCE: 0.7948, AuxCE: 1.5539, KD: 0.2930)
# Epoch [50/100], Step [291/391], Loss: 1.6083 (FinalCE: 0.7984, AuxCE: 1.5627, KD: 0.3080)
# Epoch [50/100], Step [388/391], Loss: 1.6120 (FinalCE: 0.8007, AuxCE: 1.5633, KD: 0.3101)
# Epoch [50/100], Step [391/391], Loss: 1.6106 (FinalCE: 0.8000, AuxCE: 1.5613, KD: 0.3102)
# ---> Epoch 50 Training Summary: Avg Loss: 1.6106, Final Acc: 73.57%, Time: 29.18s
# ---> Validation Summary (using final output): Loss: 1.0634, Acc: 66.72%, Time: 2.70s
#
# --- Epoch 51/100 ---
# Current Learning Rate: 0.010000
# Epoch [51/100], Step [97/391], Loss: 1.2242 (FinalCE: 0.6484, AuxCE: 1.2762, KD: 0.1089)
# Epoch [51/100], Step [194/391], Loss: 1.1094 (FinalCE: 0.5912, AuxCE: 1.1639, KD: 0.0878)
# Epoch [51/100], Step [291/391], Loss: 1.0668 (FinalCE: 0.5700, AuxCE: 1.1221, KD: 0.0801)
# Epoch [51/100], Step [388/391], Loss: 1.0419 (FinalCE: 0.5575, AuxCE: 1.0971, KD: 0.0758)
# Epoch [51/100], Step [391/391], Loss: 1.0413 (FinalCE: 0.5573, AuxCE: 1.0965, KD: 0.0757)
# ---> Epoch 51 Training Summary: Avg Loss: 1.0413, Final Acc: 81.24%, Time: 29.66s
# ---> Validation Summary (using final output): Loss: 0.5064, Acc: 82.67%, Time: 2.67s
# Validation accuracy improved (72.85% -> 82.67%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 52/100 ---
# Current Learning Rate: 0.010000
# Epoch [52/100], Step [97/391], Loss: 0.9293 (FinalCE: 0.5002, AuxCE: 0.9820, KD: 0.0605)
# Epoch [52/100], Step [194/391], Loss: 0.9358 (FinalCE: 0.5038, AuxCE: 0.9884, KD: 0.0610)
# Epoch [52/100], Step [291/391], Loss: 0.9277 (FinalCE: 0.4997, AuxCE: 0.9788, KD: 0.0609)
# Epoch [52/100], Step [388/391], Loss: 0.9180 (FinalCE: 0.4943, AuxCE: 0.9683, KD: 0.0606)
# Epoch [52/100], Step [391/391], Loss: 0.9176 (FinalCE: 0.4940, AuxCE: 0.9679, KD: 0.0606)
# ---> Epoch 52 Training Summary: Avg Loss: 0.9176, Final Acc: 83.46%, Time: 32.06s
# ---> Validation Summary (using final output): Loss: 0.4795, Acc: 83.94%, Time: 4.27s
# Validation accuracy improved (82.67% -> 83.94%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 53/100 ---
# Current Learning Rate: 0.010000
# Epoch [53/100], Step [97/391], Loss: 0.8695 (FinalCE: 0.4673, AuxCE: 0.9180, KD: 0.0584)
# Epoch [53/100], Step [194/391], Loss: 0.8698 (FinalCE: 0.4678, AuxCE: 0.9187, KD: 0.0576)
# Epoch [53/100], Step [291/391], Loss: 0.8701 (FinalCE: 0.4682, AuxCE: 0.9183, KD: 0.0577)
# Epoch [53/100], Step [388/391], Loss: 0.8682 (FinalCE: 0.4673, AuxCE: 0.9168, KD: 0.0569)
# Epoch [53/100], Step [391/391], Loss: 0.8680 (FinalCE: 0.4672, AuxCE: 0.9166, KD: 0.0569)
# ---> Epoch 53 Training Summary: Avg Loss: 0.8680, Final Acc: 84.17%, Time: 30.70s
# ---> Validation Summary (using final output): Loss: 0.4760, Acc: 83.90%, Time: 2.58s
#
# --- Epoch 54/100 ---
# Current Learning Rate: 0.010000
# Epoch [54/100], Step [97/391], Loss: 0.8283 (FinalCE: 0.4459, AuxCE: 0.8741, KD: 0.0546)
# Epoch [54/100], Step [194/391], Loss: 0.8309 (FinalCE: 0.4472, AuxCE: 0.8782, KD: 0.0541)
# Epoch [54/100], Step [291/391], Loss: 0.8326 (FinalCE: 0.4483, AuxCE: 0.8802, KD: 0.0537)
# Epoch [54/100], Step [388/391], Loss: 0.8322 (FinalCE: 0.4482, AuxCE: 0.8802, KD: 0.0532)
# Epoch [54/100], Step [391/391], Loss: 0.8321 (FinalCE: 0.4482, AuxCE: 0.8801, KD: 0.0532)
# ---> Epoch 54 Training Summary: Avg Loss: 0.8321, Final Acc: 84.79%, Time: 29.01s
# ---> Validation Summary (using final output): Loss: 0.4660, Acc: 84.19%, Time: 2.88s
# Validation accuracy improved (83.94% -> 84.19%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 55/100 ---
# Current Learning Rate: 0.010000
# Epoch [55/100], Step [97/391], Loss: 0.8027 (FinalCE: 0.4317, AuxCE: 0.8473, KD: 0.0535)
# Epoch [55/100], Step [194/391], Loss: 0.8106 (FinalCE: 0.4362, AuxCE: 0.8551, KD: 0.0539)
# Epoch [55/100], Step [291/391], Loss: 0.8047 (FinalCE: 0.4331, AuxCE: 0.8488, KD: 0.0535)
# Epoch [55/100], Step [388/391], Loss: 0.8112 (FinalCE: 0.4372, AuxCE: 0.8555, KD: 0.0531)
# Epoch [55/100], Step [391/391], Loss: 0.8113 (FinalCE: 0.4372, AuxCE: 0.8555, KD: 0.0531)
# ---> Epoch 55 Training Summary: Avg Loss: 0.8113, Final Acc: 85.08%, Time: 31.15s
# ---> Validation Summary (using final output): Loss: 0.4603, Acc: 84.40%, Time: 2.63s
# Validation accuracy improved (84.19% -> 84.40%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 56/100 ---
# Current Learning Rate: 0.010000
# Epoch [56/100], Step [97/391], Loss: 0.7791 (FinalCE: 0.4196, AuxCE: 0.8223, KD: 0.0509)
# Epoch [56/100], Step [194/391], Loss: 0.7818 (FinalCE: 0.4220, AuxCE: 0.8251, KD: 0.0497)
# Epoch [56/100], Step [291/391], Loss: 0.7848 (FinalCE: 0.4240, AuxCE: 0.8286, KD: 0.0490)
# Epoch [56/100], Step [388/391], Loss: 0.7872 (FinalCE: 0.4251, AuxCE: 0.8319, KD: 0.0489)
# Epoch [56/100], Step [391/391], Loss: 0.7875 (FinalCE: 0.4253, AuxCE: 0.8321, KD: 0.0489)
# ---> Epoch 56 Training Summary: Avg Loss: 0.7875, Final Acc: 85.63%, Time: 30.67s
# ---> Validation Summary (using final output): Loss: 0.4532, Acc: 84.91%, Time: 3.76s
# Validation accuracy improved (84.40% -> 84.91%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 57/100 ---
# Current Learning Rate: 0.010000
# Epoch [57/100], Step [97/391], Loss: 0.7683 (FinalCE: 0.4142, AuxCE: 0.8124, KD: 0.0486)
# Epoch [57/100], Step [194/391], Loss: 0.7793 (FinalCE: 0.4203, AuxCE: 0.8230, KD: 0.0496)
# Epoch [57/100], Step [291/391], Loss: 0.7736 (FinalCE: 0.4174, AuxCE: 0.8176, KD: 0.0486)
# Epoch [57/100], Step [388/391], Loss: 0.7743 (FinalCE: 0.4180, AuxCE: 0.8186, KD: 0.0481)
# Epoch [57/100], Step [391/391], Loss: 0.7743 (FinalCE: 0.4181, AuxCE: 0.8186, KD: 0.0481)
# ---> Epoch 57 Training Summary: Avg Loss: 0.7743, Final Acc: 85.73%, Time: 31.31s
# ---> Validation Summary (using final output): Loss: 0.4613, Acc: 84.29%, Time: 2.63s
#
# --- Epoch 58/100 ---
# Current Learning Rate: 0.010000
# Epoch [58/100], Step [97/391], Loss: 0.7281 (FinalCE: 0.3916, AuxCE: 0.7685, KD: 0.0486)
# Epoch [58/100], Step [194/391], Loss: 0.7493 (FinalCE: 0.4033, AuxCE: 0.7913, KD: 0.0492)
# Epoch [58/100], Step [291/391], Loss: 0.7529 (FinalCE: 0.4058, AuxCE: 0.7942, KD: 0.0490)
# Epoch [58/100], Step [388/391], Loss: 0.7549 (FinalCE: 0.4072, AuxCE: 0.7965, KD: 0.0485)
# Epoch [58/100], Step [391/391], Loss: 0.7544 (FinalCE: 0.4069, AuxCE: 0.7959, KD: 0.0485)
# ---> Epoch 58 Training Summary: Avg Loss: 0.7544, Final Acc: 86.13%, Time: 29.02s
# ---> Validation Summary (using final output): Loss: 0.4618, Acc: 84.33%, Time: 2.64s
#
# --- Epoch 59/100 ---
# Current Learning Rate: 0.010000
# Epoch [59/100], Step [97/391], Loss: 0.7176 (FinalCE: 0.3868, AuxCE: 0.7566, KD: 0.0468)
# Epoch [59/100], Step [194/391], Loss: 0.7293 (FinalCE: 0.3932, AuxCE: 0.7701, KD: 0.0468)
# Epoch [59/100], Step [291/391], Loss: 0.7361 (FinalCE: 0.3969, AuxCE: 0.7775, KD: 0.0469)
# Epoch [59/100], Step [388/391], Loss: 0.7380 (FinalCE: 0.3980, AuxCE: 0.7791, KD: 0.0472)
# Epoch [59/100], Step [391/391], Loss: 0.7372 (FinalCE: 0.3976, AuxCE: 0.7783, KD: 0.0472)
# ---> Epoch 59 Training Summary: Avg Loss: 0.7372, Final Acc: 86.54%, Time: 28.90s
# ---> Validation Summary (using final output): Loss: 0.4473, Acc: 84.88%, Time: 3.31s
#
# --- Epoch 60/100 ---
# Current Learning Rate: 0.010000
# Epoch [60/100], Step [97/391], Loss: 0.7248 (FinalCE: 0.3907, AuxCE: 0.7670, KD: 0.0454)
# Epoch [60/100], Step [194/391], Loss: 0.7243 (FinalCE: 0.3899, AuxCE: 0.7645, KD: 0.0476)
# Epoch [60/100], Step [291/391], Loss: 0.7236 (FinalCE: 0.3898, AuxCE: 0.7640, KD: 0.0470)
# Epoch [60/100], Step [388/391], Loss: 0.7322 (FinalCE: 0.3950, AuxCE: 0.7735, KD: 0.0463)
# Epoch [60/100], Step [391/391], Loss: 0.7317 (FinalCE: 0.3947, AuxCE: 0.7730, KD: 0.0463)
# ---> Epoch 60 Training Summary: Avg Loss: 0.7317, Final Acc: 86.43%, Time: 29.52s
# ---> Validation Summary (using final output): Loss: 0.4566, Acc: 84.42%, Time: 2.57s
#
# --- Epoch 61/100 ---
# Current Learning Rate: 0.010000
# Epoch [61/100], Step [97/391], Loss: 0.7063 (FinalCE: 0.3798, AuxCE: 0.7428, KD: 0.0489)
# Epoch [61/100], Step [194/391], Loss: 0.7052 (FinalCE: 0.3798, AuxCE: 0.7426, KD: 0.0474)
# Epoch [61/100], Step [291/391], Loss: 0.7143 (FinalCE: 0.3844, AuxCE: 0.7528, KD: 0.0479)
# Epoch [61/100], Step [388/391], Loss: 0.7179 (FinalCE: 0.3865, AuxCE: 0.7567, KD: 0.0478)
# Epoch [61/100], Step [391/391], Loss: 0.7183 (FinalCE: 0.3868, AuxCE: 0.7571, KD: 0.0478)
# ---> Epoch 61 Training Summary: Avg Loss: 0.7183, Final Acc: 86.79%, Time: 30.30s
# ---> Validation Summary (using final output): Loss: 0.4557, Acc: 84.62%, Time: 2.58s
#
# --- Epoch 62/100 ---
# Current Learning Rate: 0.010000
# Epoch [62/100], Step [97/391], Loss: 0.6809 (FinalCE: 0.3669, AuxCE: 0.7159, KD: 0.0461)
# Epoch [62/100], Step [194/391], Loss: 0.7069 (FinalCE: 0.3811, AuxCE: 0.7441, KD: 0.0469)
# Epoch [62/100], Step [291/391], Loss: 0.7090 (FinalCE: 0.3820, AuxCE: 0.7462, KD: 0.0476)
# Epoch [62/100], Step [388/391], Loss: 0.7082 (FinalCE: 0.3815, AuxCE: 0.7452, KD: 0.0478)
# Epoch [62/100], Step [391/391], Loss: 0.7101 (FinalCE: 0.3825, AuxCE: 0.7473, KD: 0.0478)
# ---> Epoch 62 Training Summary: Avg Loss: 0.7101, Final Acc: 86.94%, Time: 29.07s
# ---> Validation Summary (using final output): Loss: 0.4683, Acc: 84.39%, Time: 3.83s
#
# --- Epoch 63/100 ---
# Current Learning Rate: 0.010000
# Epoch [63/100], Step [97/391], Loss: 0.6953 (FinalCE: 0.3741, AuxCE: 0.7327, KD: 0.0467)
# Epoch [63/100], Step [194/391], Loss: 0.6976 (FinalCE: 0.3755, AuxCE: 0.7352, KD: 0.0467)
# Epoch [63/100], Step [291/391], Loss: 0.7058 (FinalCE: 0.3801, AuxCE: 0.7429, KD: 0.0476)
# Epoch [63/100], Step [388/391], Loss: 0.6992 (FinalCE: 0.3766, AuxCE: 0.7360, KD: 0.0470)
# Epoch [63/100], Step [391/391], Loss: 0.6985 (FinalCE: 0.3762, AuxCE: 0.7353, KD: 0.0470)
# ...
# Epoch [79/100], Step [391/391], Loss: 0.4271 (FinalCE: 0.2270, AuxCE: 0.4507, KD: 0.0331)
# ---> Epoch 79 Training Summary: Avg Loss: 0.4271, Final Acc: 92.24%, Time: 29.00s
# ---> Validation Summary (using final output): Loss: 0.3887, Acc: 87.61%, Time: 3.74s
# Validation accuracy improved (87.56% -> 87.61%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 80/100 ---
# Current Learning Rate: 0.001000
# Epoch [80/100], Step [97/391], Loss: 0.4067 (FinalCE: 0.2153, AuxCE: 0.4290, KD: 0.0329)
# Epoch [80/100], Step [194/391], Loss: 0.4106 (FinalCE: 0.2176, AuxCE: 0.4327, KD: 0.0332)
# Epoch [80/100], Step [291/391], Loss: 0.4077 (FinalCE: 0.2158, AuxCE: 0.4299, KD: 0.0332)
# Epoch [80/100], Step [388/391], Loss: 0.4123 (FinalCE: 0.2183, AuxCE: 0.4349, KD: 0.0334)
# Epoch [80/100], Step [391/391], Loss: 0.4120 (FinalCE: 0.2181, AuxCE: 0.4345, KD: 0.0334)
# ---> Epoch 80 Training Summary: Avg Loss: 0.4120, Final Acc: 92.44%, Time: 30.71s
# ---> Validation Summary (using final output): Loss: 0.3856, Acc: 87.57%, Time: 2.77s
#
# --- Epoch 81/100 ---
# Current Learning Rate: 0.001000
# Epoch [81/100], Step [97/391], Loss: 0.3951 (FinalCE: 0.2088, AuxCE: 0.4148, KD: 0.0340)
# Epoch [81/100], Step [194/391], Loss: 0.4036 (FinalCE: 0.2135, AuxCE: 0.4240, KD: 0.0342)
# Epoch [81/100], Step [291/391], Loss: 0.4061 (FinalCE: 0.2147, AuxCE: 0.4270, KD: 0.0342)
# Epoch [81/100], Step [388/391], Loss: 0.4090 (FinalCE: 0.2164, AuxCE: 0.4301, KD: 0.0342)
# Epoch [81/100], Step [391/391], Loss: 0.4086 (FinalCE: 0.2162, AuxCE: 0.4297, KD: 0.0342)
# ---> Epoch 81 Training Summary: Avg Loss: 0.4086, Final Acc: 92.58%, Time: 29.26s
# ---> Validation Summary (using final output): Loss: 0.3892, Acc: 87.53%, Time: 2.74s
#
# --- Epoch 82/100 ---
# Current Learning Rate: 0.001000
# Epoch [82/100], Step [97/391], Loss: 0.3984 (FinalCE: 0.2104, AuxCE: 0.4187, KD: 0.0342)
# Epoch [82/100], Step [194/391], Loss: 0.3989 (FinalCE: 0.2104, AuxCE: 0.4195, KD: 0.0345)
# Epoch [82/100], Step [291/391], Loss: 0.4005 (FinalCE: 0.2112, AuxCE: 0.4216, KD: 0.0343)
# Epoch [82/100], Step [388/391], Loss: 0.4008 (FinalCE: 0.2114, AuxCE: 0.4218, KD: 0.0345)
# Epoch [82/100], Step [391/391], Loss: 0.4015 (FinalCE: 0.2118, AuxCE: 0.4225, KD: 0.0345)
# ---> Epoch 82 Training Summary: Avg Loss: 0.4015, Final Acc: 92.89%, Time: 31.17s
# ---> Validation Summary (using final output): Loss: 0.3874, Acc: 87.62%, Time: 2.75s
# Validation accuracy improved (87.61% -> 87.62%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 83/100 ---
# Current Learning Rate: 0.001000
# Epoch [83/100], Step [97/391], Loss: 0.3813 (FinalCE: 0.2004, AuxCE: 0.4003, KD: 0.0345)
# Epoch [83/100], Step [194/391], Loss: 0.3870 (FinalCE: 0.2037, AuxCE: 0.4065, KD: 0.0344)
# Epoch [83/100], Step [291/391], Loss: 0.3837 (FinalCE: 0.2019, AuxCE: 0.4025, KD: 0.0346)
# Epoch [83/100], Step [388/391], Loss: 0.3889 (FinalCE: 0.2048, AuxCE: 0.4083, KD: 0.0347)
# Epoch [83/100], Step [391/391], Loss: 0.3888 (FinalCE: 0.2047, AuxCE: 0.4081, KD: 0.0347)
# ---> Epoch 83 Training Summary: Avg Loss: 0.3888, Final Acc: 93.14%, Time: 30.15s
# ---> Validation Summary (using final output): Loss: 0.3895, Acc: 87.57%, Time: 2.60s
#
# --- Epoch 84/100 ---
# Current Learning Rate: 0.001000
# Epoch [84/100], Step [97/391], Loss: 0.3853 (FinalCE: 0.2026, AuxCE: 0.4037, KD: 0.0354)
# Epoch [84/100], Step [194/391], Loss: 0.3904 (FinalCE: 0.2054, AuxCE: 0.4091, KD: 0.0356)
# Epoch [84/100], Step [291/391], Loss: 0.3874 (FinalCE: 0.2036, AuxCE: 0.4063, KD: 0.0355)
# Epoch [84/100], Step [388/391], Loss: 0.3875 (FinalCE: 0.2037, AuxCE: 0.4062, KD: 0.0356)
# Epoch [84/100], Step [391/391], Loss: 0.3869 (FinalCE: 0.2033, AuxCE: 0.4055, KD: 0.0356)
# ---> Epoch 84 Training Summary: Avg Loss: 0.3869, Final Acc: 93.10%, Time: 29.28s
# ---> Validation Summary (using final output): Loss: 0.3895, Acc: 87.66%, Time: 3.59s
# Validation accuracy improved (87.62% -> 87.66%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 85/100 ---
# Current Learning Rate: 0.001000
# Epoch [85/100], Step [97/391], Loss: 0.3856 (FinalCE: 0.2023, AuxCE: 0.4033, KD: 0.0366)
# Epoch [85/100], Step [194/391], Loss: 0.3833 (FinalCE: 0.2010, AuxCE: 0.4012, KD: 0.0362)
# Epoch [85/100], Step [291/391], Loss: 0.3781 (FinalCE: 0.1982, AuxCE: 0.3956, KD: 0.0361)
# Epoch [85/100], Step [388/391], Loss: 0.3839 (FinalCE: 0.2015, AuxCE: 0.4019, KD: 0.0360)
# Epoch [85/100], Step [391/391], Loss: 0.3835 (FinalCE: 0.2012, AuxCE: 0.4015, KD: 0.0360)
# ---> Epoch 85 Training Summary: Avg Loss: 0.3835, Final Acc: 93.11%, Time: 30.91s
# ---> Validation Summary (using final output): Loss: 0.3899, Acc: 87.67%, Time: 2.56s
# Validation accuracy improved (87.66% -> 87.67%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 86/100 ---
# Current Learning Rate: 0.001000
# Epoch [86/100], Step [97/391], Loss: 0.3665 (FinalCE: 0.1920, AuxCE: 0.3816, KD: 0.0364)
# Epoch [86/100], Step [194/391], Loss: 0.3785 (FinalCE: 0.1985, AuxCE: 0.3951, KD: 0.0366)
# Epoch [86/100], Step [291/391], Loss: 0.3755 (FinalCE: 0.1967, AuxCE: 0.3921, KD: 0.0366)
# Epoch [86/100], Step [388/391], Loss: 0.3791 (FinalCE: 0.1986, AuxCE: 0.3961, KD: 0.0367)
# Epoch [86/100], Step [391/391], Loss: 0.3798 (FinalCE: 0.1990, AuxCE: 0.3970, KD: 0.0367)
# ---> Epoch 86 Training Summary: Avg Loss: 0.3798, Final Acc: 93.30%, Time: 31.90s
# ---> Validation Summary (using final output): Loss: 0.3909, Acc: 87.55%, Time: 3.87s
#
# --- Epoch 87/100 ---
# Current Learning Rate: 0.001000
# Epoch [87/100], Step [97/391], Loss: 0.3705 (FinalCE: 0.1933, AuxCE: 0.3873, KD: 0.0371)
# Epoch [87/100], Step [194/391], Loss: 0.3779 (FinalCE: 0.1975, AuxCE: 0.3950, KD: 0.0372)
# Epoch [87/100], Step [291/391], Loss: 0.3751 (FinalCE: 0.1961, AuxCE: 0.3919, KD: 0.0371)
# Epoch [87/100], Step [388/391], Loss: 0.3761 (FinalCE: 0.1968, AuxCE: 0.3928, KD: 0.0371)
# Epoch [87/100], Step [391/391], Loss: 0.3763 (FinalCE: 0.1969, AuxCE: 0.3928, KD: 0.0371)
# ---> Epoch 87 Training Summary: Avg Loss: 0.3763, Final Acc: 93.27%, Time: 28.87s
# ---> Validation Summary (using final output): Loss: 0.3959, Acc: 87.34%, Time: 2.58s
#
# --- Epoch 88/100 ---
# Current Learning Rate: 0.001000
# Epoch [88/100], Step [97/391], Loss: 0.3732 (FinalCE: 0.1950, AuxCE: 0.3890, KD: 0.0376)
# Epoch [88/100], Step [194/391], Loss: 0.3703 (FinalCE: 0.1935, AuxCE: 0.3859, KD: 0.0374)
# Epoch [88/100], Step [291/391], Loss: 0.3651 (FinalCE: 0.1905, AuxCE: 0.3802, KD: 0.0374)
# Epoch [88/100], Step [388/391], Loss: 0.3696 (FinalCE: 0.1930, AuxCE: 0.3851, KD: 0.0377)
# Epoch [88/100], Step [391/391], Loss: 0.3702 (FinalCE: 0.1933, AuxCE: 0.3857, KD: 0.0377)
# ---> Epoch 88 Training Summary: Avg Loss: 0.3702, Final Acc: 93.48%, Time: 28.75s
# ---> Validation Summary (using final output): Loss: 0.3900, Acc: 87.81%, Time: 2.52s
# Validation accuracy improved (87.67% -> 87.81%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 89/100 ---
# Current Learning Rate: 0.001000
# Epoch [89/100], Step [97/391], Loss: 0.3720 (FinalCE: 0.1941, AuxCE: 0.3879, KD: 0.0380)
# Epoch [89/100], Step [194/391], Loss: 0.3630 (FinalCE: 0.1891, AuxCE: 0.3780, KD: 0.0379)
# Epoch [89/100], Step [291/391], Loss: 0.3640 (FinalCE: 0.1897, AuxCE: 0.3787, KD: 0.0380)
# Epoch [89/100], Step [388/391], Loss: 0.3695 (FinalCE: 0.1928, AuxCE: 0.3846, KD: 0.0381)
# Epoch [89/100], Step [391/391], Loss: 0.3701 (FinalCE: 0.1932, AuxCE: 0.3853, KD: 0.0380)
# ---> Epoch 89 Training Summary: Avg Loss: 0.3701, Final Acc: 93.40%, Time: 30.35s
# ---> Validation Summary (using final output): Loss: 0.3974, Acc: 87.57%, Time: 3.34s
#
# --- Epoch 90/100 ---
# Current Learning Rate: 0.001000
# Epoch [90/100], Step [97/391], Loss: 0.3607 (FinalCE: 0.1877, AuxCE: 0.3749, KD: 0.0383)
# Epoch [90/100], Step [194/391], Loss: 0.3657 (FinalCE: 0.1903, AuxCE: 0.3801, KD: 0.0390)
# Epoch [90/100], Step [291/391], Loss: 0.3687 (FinalCE: 0.1920, AuxCE: 0.3839, KD: 0.0386)
# Epoch [90/100], Step [388/391], Loss: 0.3698 (FinalCE: 0.1926, AuxCE: 0.3850, KD: 0.0386)
# Epoch [90/100], Step [391/391], Loss: 0.3689 (FinalCE: 0.1921, AuxCE: 0.3841, KD: 0.0386)
# ---> Epoch 90 Training Summary: Avg Loss: 0.3689, Final Acc: 93.47%, Time: 28.81s
# ---> Validation Summary (using final output): Loss: 0.4009, Acc: 87.65%, Time: 2.65s
#
# --- Epoch 91/100 ---
# Current Learning Rate: 0.001000
# Epoch [91/100], Step [97/391], Loss: 0.3407 (FinalCE: 0.1766, AuxCE: 0.3527, KD: 0.0383)
# Epoch [91/100], Step [194/391], Loss: 0.3548 (FinalCE: 0.1842, AuxCE: 0.3683, KD: 0.0388)
# Epoch [91/100], Step [291/391], Loss: 0.3563 (FinalCE: 0.1850, AuxCE: 0.3699, KD: 0.0389)
# Epoch [91/100], Step [388/391], Loss: 0.3563 (FinalCE: 0.1850, AuxCE: 0.3698, KD: 0.0390)
# Epoch [91/100], Step [391/391], Loss: 0.3560 (FinalCE: 0.1848, AuxCE: 0.3694, KD: 0.0390)
# ---> Epoch 91 Training Summary: Avg Loss: 0.3560, Final Acc: 93.72%, Time: 30.19s
# ---> Validation Summary (using final output): Loss: 0.4006, Acc: 87.68%, Time: 2.60s
#
# --- Epoch 92/100 ---
# Current Learning Rate: 0.001000
# Epoch [92/100], Step [97/391], Loss: 0.3552 (FinalCE: 0.1848, AuxCE: 0.3686, KD: 0.0384)
# Epoch [92/100], Step [194/391], Loss: 0.3548 (FinalCE: 0.1841, AuxCE: 0.3681, KD: 0.0391)
# Epoch [92/100], Step [291/391], Loss: 0.3476 (FinalCE: 0.1800, AuxCE: 0.3603, KD: 0.0391)
# Epoch [92/100], Step [388/391], Loss: 0.3542 (FinalCE: 0.1838, AuxCE: 0.3677, KD: 0.0390)
# Epoch [92/100], Step [391/391], Loss: 0.3546 (FinalCE: 0.1840, AuxCE: 0.3679, KD: 0.0390)
# ---> Epoch 92 Training Summary: Avg Loss: 0.3546, Final Acc: 93.77%, Time: 28.69s
# ---> Validation Summary (using final output): Loss: 0.4005, Acc: 87.65%, Time: 3.72s
#
# --- Epoch 93/100 ---
# Current Learning Rate: 0.001000
# Epoch [93/100], Step [97/391], Loss: 0.3440 (FinalCE: 0.1782, AuxCE: 0.3563, KD: 0.0387)
# Epoch [93/100], Step [194/391], Loss: 0.3405 (FinalCE: 0.1760, AuxCE: 0.3529, KD: 0.0390)
# Epoch [93/100], Step [291/391], Loss: 0.3412 (FinalCE: 0.1765, AuxCE: 0.3533, KD: 0.0390)
# Epoch [93/100], Step [388/391], Loss: 0.3481 (FinalCE: 0.1803, AuxCE: 0.3607, KD: 0.0392)
# Epoch [93/100], Step [391/391], Loss: 0.3485 (FinalCE: 0.1805, AuxCE: 0.3611, KD: 0.0393)
# ---> Epoch 93 Training Summary: Avg Loss: 0.3485, Final Acc: 93.79%, Time: 28.78s
# ---> Validation Summary (using final output): Loss: 0.3973, Acc: 87.94%, Time: 2.68s
# Validation accuracy improved (87.81% -> 87.94%). Saving model...
# Model saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth
#
# --- Epoch 94/100 ---
# Current Learning Rate: 0.001000
# Epoch [94/100], Step [97/391], Loss: 0.3419 (FinalCE: 0.1766, AuxCE: 0.3539, KD: 0.0396)
# Epoch [94/100], Step [194/391], Loss: 0.3461 (FinalCE: 0.1788, AuxCE: 0.3576, KD: 0.0403)
# Epoch [94/100], Step [291/391], Loss: 0.3460 (FinalCE: 0.1788, AuxCE: 0.3576, KD: 0.0402)
# Epoch [94/100], Step [388/391], Loss: 0.3486 (FinalCE: 0.1803, AuxCE: 0.3605, KD: 0.0402)
# Epoch [94/100], Step [391/391], Loss: 0.3485 (FinalCE: 0.1802, AuxCE: 0.3604, KD: 0.0402)
# ---> Epoch 94 Training Summary: Avg Loss: 0.3485, Final Acc: 93.75%, Time: 29.47s
# ---> Validation Summary (using final output): Loss: 0.4057, Acc: 87.69%, Time: 2.58s
#
# --- Epoch 95/100 ---
# Current Learning Rate: 0.001000
# Epoch [95/100], Step [97/391], Loss: 0.3524 (FinalCE: 0.1818, AuxCE: 0.3649, KD: 0.0410)
# Epoch [95/100], Step [194/391], Loss: 0.3434 (FinalCE: 0.1768, AuxCE: 0.3545, KD: 0.0413)
# Epoch [95/100], Step [291/391], Loss: 0.3424 (FinalCE: 0.1764, AuxCE: 0.3536, KD: 0.0410)
# Epoch [95/100], Step [388/391], Loss: 0.3446 (FinalCE: 0.1776, AuxCE: 0.3559, KD: 0.0410)
# Epoch [95/100], Step [391/391], Loss: 0.3454 (FinalCE: 0.1781, AuxCE: 0.3567, KD: 0.0411)
# ---> Epoch 95 Training Summary: Avg Loss: 0.3454, Final Acc: 93.89%, Time: 30.42s
# ---> Validation Summary (using final output): Loss: 0.4063, Acc: 87.51%, Time: 4.00s
#
# --- Epoch 96/100 ---
# Current Learning Rate: 0.001000
# Epoch [96/100], Step [97/391], Loss: 0.3334 (FinalCE: 0.1714, AuxCE: 0.3434, KD: 0.0411)
# Epoch [96/100], Step [194/391], Loss: 0.3371 (FinalCE: 0.1735, AuxCE: 0.3469, KD: 0.0414)
# Epoch [96/100], Step [291/391], Loss: 0.3399 (FinalCE: 0.1748, AuxCE: 0.3502, KD: 0.0417)
# Epoch [96/100], Step [388/391], Loss: 0.3377 (FinalCE: 0.1736, AuxCE: 0.3474, KD: 0.0420)
# Epoch [96/100], Step [391/391], Loss: 0.3374 (FinalCE: 0.1734, AuxCE: 0.3472, KD: 0.0419)
# ---> Epoch 96 Training Summary: Avg Loss: 0.3374, Final Acc: 94.19%, Time: 28.58s
# ---> Validation Summary (using final output): Loss: 0.4060, Acc: 87.75%, Time: 2.60s
#
# --- Epoch 97/100 ---
# Current Learning Rate: 0.001000
# Epoch [97/100], Step [97/391], Loss: 0.3259 (FinalCE: 0.1666, AuxCE: 0.3351, KD: 0.0420)
# Epoch [97/100], Step [194/391], Loss: 0.3345 (FinalCE: 0.1718, AuxCE: 0.3434, KD: 0.0422)
# Epoch [97/100], Step [291/391], Loss: 0.3364 (FinalCE: 0.1729, AuxCE: 0.3452, KD: 0.0424)
# Epoch [97/100], Step [388/391], Loss: 0.3342 (FinalCE: 0.1717, AuxCE: 0.3428, KD: 0.0423)
# Epoch [97/100], Step [391/391], Loss: 0.3346 (FinalCE: 0.1719, AuxCE: 0.3433, KD: 0.0423)
# ---> Epoch 97 Training Summary: Avg Loss: 0.3346, Final Acc: 94.11%, Time: 28.62s
# ---> Validation Summary (using final output): Loss: 0.4132, Acc: 87.41%, Time: 2.56s
#
# --- Epoch 98/100 ---
# Current Learning Rate: 0.001000
# Epoch [98/100], Step [97/391], Loss: 0.3294 (FinalCE: 0.1687, AuxCE: 0.3388, KD: 0.0419)
# Epoch [98/100], Step [194/391], Loss: 0.3303 (FinalCE: 0.1694, AuxCE: 0.3403, KD: 0.0412)
# Epoch [98/100], Step [291/391], Loss: 0.3343 (FinalCE: 0.1718, AuxCE: 0.3442, KD: 0.0414)
# Epoch [98/100], Step [388/391], Loss: 0.3359 (FinalCE: 0.1726, AuxCE: 0.3460, KD: 0.0414)
# Epoch [98/100], Step [391/391], Loss: 0.3358 (FinalCE: 0.1726, AuxCE: 0.3460, KD: 0.0414)
# ---> Epoch 98 Training Summary: Avg Loss: 0.3358, Final Acc: 94.15%, Time: 28.62s
# ---> Validation Summary (using final output): Loss: 0.4105, Acc: 87.55%, Time: 3.18s
#
# --- Epoch 99/100 ---
# Current Learning Rate: 0.001000
# Epoch [99/100], Step [97/391], Loss: 0.3266 (FinalCE: 0.1674, AuxCE: 0.3346, KD: 0.0423)
# Epoch [99/100], Step [194/391], Loss: 0.3396 (FinalCE: 0.1747, AuxCE: 0.3493, KD: 0.0420)
# Epoch [99/100], Step [291/391], Loss: 0.3375 (FinalCE: 0.1735, AuxCE: 0.3471, KD: 0.0419)
# Epoch [99/100], Step [388/391], Loss: 0.3365 (FinalCE: 0.1728, AuxCE: 0.3464, KD: 0.0419)
# Epoch [99/100], Step [391/391], Loss: 0.3366 (FinalCE: 0.1728, AuxCE: 0.3464, KD: 0.0420)
# ---> Epoch 99 Training Summary: Avg Loss: 0.3366, Final Acc: 94.08%, Time: 29.20s
# ---> Validation Summary (using final output): Loss: 0.4106, Acc: 87.55%, Time: 2.73s
#
# --- Epoch 100/100 ---
# Current Learning Rate: 0.001000
# Epoch [100/100], Step [97/391], Loss: 0.3186 (FinalCE: 0.1622, AuxCE: 0.3273, KD: 0.0424)
# Epoch [100/100], Step [194/391], Loss: 0.3280 (FinalCE: 0.1679, AuxCE: 0.3370, KD: 0.0420)
# Epoch [100/100], Step [291/391], Loss: 0.3312 (FinalCE: 0.1697, AuxCE: 0.3407, KD: 0.0420)
# Epoch [100/100], Step [388/391], Loss: 0.3323 (FinalCE: 0.1704, AuxCE: 0.3416, KD: 0.0421)
# Epoch [100/100], Step [391/391], Loss: 0.3325 (FinalCE: 0.1705, AuxCE: 0.3419, KD: 0.0421)
# ---> Epoch 100 Training Summary: Avg Loss: 0.3325, Final Acc: 94.18%, Time: 29.56s
# ---> Validation Summary (using final output): Loss: 0.4121, Acc: 87.79%, Time: 2.56s
#
# Finished Self-Distillation Training.
# Total Training Time: 54m 11s
# Best Validation Accuracy achieved (on final layer): 87.94%
# Best model saved at: /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/models/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6.pth

# %% [markdown]
# Plotting Results

# %%
print("\nPlotting training history...")

epochs_range = range(1, EPOCHS + 1)

plt.figure(figsize=(14, 5))

# Plot Loss (Displays total weighted training loss vs final layer validation loss)
plt.subplot(1, 3, 1)
plt.plot(epochs_range, history['train_loss'], label='Train Loss (Total Weighted)')
plt.plot(epochs_range, history['val_loss'], label='Validation Loss (Final Layer)')
plt.title('Loss over Epochs (ResNet-50 Self-Distill)') # Updated title
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot Accuracy (Displays final layer training accuracy vs final layer validation accuracy)
plt.subplot(1, 3, 2)
plt.plot(epochs_range, history['train_acc'], label='Train Accuracy (Final Layer)')
plt.plot(epochs_range, history['val_acc'], label='Validation Accuracy (Final Layer)')
plt.title('Accuracy over Epochs (ResNet-50 Self-Distill)') # Updated title
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

# Plot Learning Rate
plt.subplot(1, 3, 3)
plt.plot(epochs_range, history['lr'], label='Learning Rate')
plt.title('Learning Rate over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.grid(True)

plt.tight_layout()
# Save the plot using the path defined in Cell 2
try:
    plt.savefig(PLOT_SAVE_PATH)
    print(f"Plot saved to {PLOT_SAVE_PATH}")
except Exception as e:
    print(f"Error saving plot to {PLOT_SAVE_PATH}: {e}")

plt.show()
# Out:
# Plotting training history...
# Plot saved to /content/drive/MyDrive/ECE 661 Final Project: Knowledge Distillation/A_Jerry_SelfDistillation/results/resnet50_self_distill_T3.0_Waux0.4_Wkd0.6_curves.png

# %% [markdown]
# Final Test with Best Model

# %%
print("\nEvaluating the best self-distillation model on the test set...")

# --- Instantiate the ResNet50_SD architecture again ---
# Important: Instantiate the *same* custom model used for training
base_model_for_eval = torchvision.models.resnet50(weights=None) # Need the base structure again
best_model = ResNet50_SD(base_model_for_eval, num_classes=NUM_CLASSES)
# --- End of instantiation ---

try:
    # Load the best model weights saved during training (using path from Cell 2)
    best_model.load_state_dict(torch.load(MODEL_SAVE_PATH))
    best_model.to(DEVICE)
    print("Best self-distillation model weights loaded successfully.")

    # Perform final validation using the loaded best model
    # Use the specific validation function that only evaluates the final output
    final_loss, final_acc = validate_sd(best_model, testloader, criterion_ce, DEVICE)
    print(f"\nFinal Test Accuracy of the best ResNet-50 Self-Distillation model: {final_acc:.2f}%")

    # --- Compare with baseline ---
    baseline_acc = 87.68 # <-- Paste your baseline accuracy here
    print(f"Baseline ResNet-50 Test Accuracy: {baseline_acc:.2f}%")
    improvement = final_acc - baseline_acc
    print(f"Improvement due to Self-Distillation: {improvement:.2f}%")


except FileNotFoundError:
    print(f"Error: Model file not found at {MODEL_SAVE_PATH}. Ensure training completed and saved the file.")
except Exception as e:
    print(f"An error occurred while loading or evaluating the model: {e}")
# Out:
# Evaluating the best self-distillation model on the test set...
# Auxiliary classifiers added after layer2 and layer3.
# Best self-distillation model weights loaded successfully.
# ---> Validation Summary (using final output): Loss: 0.3973, Acc: 87.94%, Time: 3.56s
#
# Final Test Accuracy of the best ResNet-50 Self-Distillation model: 87.94%
# Baseline ResNet-50 Test Accuracy: 87.68%
# Improvement due to Self-Distillation: 0.26%
